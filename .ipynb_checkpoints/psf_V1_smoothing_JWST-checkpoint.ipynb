# %%
import numpy as np
from astropy.io import fits
from spectral_cube import SpectralCube
from scipy.signal import fftconvolve
from scipy.fftpack import fft2, ifft2, fftshift
import stpsf
import astropy.units as u
import os

# %%
from glob import glob
# This is for line files. If you want to use CASA in python to get the line file,
# I will upload the code soon of a repo and link here! Sorry for now!
# However you can use your own line file just make sure the jwst psf target wavelength is same to the 
# gaussian smoothed line file you have!

# ---------- USER PARAMETERS ----------
IN_DIR  = "../../github/astr796_25_V2/NGC253_output/3channel/casa/atomic"
OUT_DIR = "../../github/astr796_25_V2/NGC253_output/3channel/jwst_psf/V1/line_smooth"
REF_CUBE = "../../github/astr796_25_V2/NGC253_output/3channel/casa/atomic/NGC253_PIII_17.9.line.fits"
TARGET_LAMBDA = 17.8846  # µm
FILE_GLOB = os.path.join(IN_DIR, "*.fits")
# ------------------------------------

os.makedirs(OUT_DIR, exist_ok=True)
files = sorted(glob(FILE_GLOB))

# --- Load reference cube to get pixel scale ---
with fits.open(REF_CUBE) as ref:
    hdr_ref = ref[0].header
    pixscale = abs(hdr_ref["CDELT2"]) * 3600.0  # arcsec/pixel

# --- Compute PSF kernel once ---
miri = stpsf.MIRI()
miri.mode = 'IFU'
miri.band = '3C'
miri.pixelscale = pixscale

psf = miri.calc_psf(monochromatic=TARGET_LAMBDA * u.micron)
psf_kernel = psf[1].data.astype(float)
psf_kernel /= psf_kernel.sum()

# --- Process each cube ---
for infile in files:
    print(f"Processing: {os.path.basename(infile)}")

    flux = fits.getdata(infile, hdu=1)
    hdr  = fits.getheader(infile, hdu=1)

    nlam = flux.shape[0]
    sm_flux = np.zeros_like(flux)

    for i in range(nlam):

        img = np.nan_to_num(flux[i], nan=0.0)
        mask = (~np.isnan(flux[i])).astype(float)

        sm = fftconvolve(img, psf_kernel, mode='same')
        sm[mask == 0] = np.nan
        sm_flux[i] = sm

    outname = os.path.join(OUT_DIR, os.path.basename(infile).replace(".fits", "_smooth.fits"))
    fits.writeto(outname, sm_flux, hdr, overwrite=True)
    print(f" → Saved: {outname}")

print("All cubes smoothed successfully.")

# %%
## Trying to correctly pass the header:
import glob
from astropy.wcs import WCS
from reproject import reproject_interp
# --- paths ---
smooth_dir = "../../github/astr796_25_V2/NGC253_output/3channel/jwst_psf/line_smooth"
out_dir = "../../github/astr796_25_V2/NGC253_output/3channel/jwst_psf/line_regrid"
os.makedirs(out_dir, exist_ok=True)

# Reference cube (Fe II or ch4)
ref_path = os.path.join(smooth_dir, "NGC253_PIII_17.9.line_smooth.fits")
with fits.open(ref_path) as ref_hdul:
    ref_hdr = ref_hdul[0].header.copy()
    ref_data = ref_hdul[0].data.copy()
ref_wcs_3d = WCS(ref_hdr)
ref_wcs_2d = ref_wcs_3d.dropaxis(2)
ref_hdr_2d = ref_wcs_2d.to_header()
ny_ref, nx_ref = ref_data.shape[1], ref_data.shape[2]
shape_out_ref = (ny_ref, nx_ref)

# --- Input cubes ---
cube_files = sorted(glob.glob(os.path.join(smooth_dir, "*.fits")))
print(f"Found {len(cube_files)} smoothed cubes.")

for infile in cube_files:
    name = os.path.basename(infile)
    outfile = os.path.join(out_dir, name.replace(".fits", "_regrid.fits"))

    # --- Read input cube ---
    data_in = fits.getdata(infile)
    hdr_in = fits.getheader(infile)
    wcs_in_3d = WCS(hdr_in)
    wcs_in_2d = wcs_in_3d.dropaxis(2)
    hdr_in_2d = wcs_in_2d.to_header()

    nlam = data_in.shape[0]
    print(f"Regridding {name}: {nlam} slices -> {shape_out_ref}")

    # --- Reproject slice by slice ---
    regridded = np.empty((nlam, ny_ref, nx_ref), dtype=np.float32)
    for i in range(nlam):
        plane = data_in[i].astype(float)
        plane_masked = np.where(np.isfinite(plane), plane, np.nan)
        out_plane, _ = reproject_interp((plane_masked, hdr_in_2d),
                                        ref_hdr_2d, shape_out=shape_out_ref)
        regridded[i] = out_plane

    # --- Build output header ---
    out_hdr = ref_hdr.copy()
    out_hdr["NAXIS3"] = nlam
    for key in hdr_in:
        if "3" in key or key.startswith("REST") or key.startswith("SPECSYS"):
            out_hdr[key] = hdr_in[key]



    fits.writeto(outfile, regridded, out_hdr, overwrite=True)
    print(f"  → wrote {outfile} shape={regridded.shape}")

print("All smoothed cubes regridded successfully.")

# %%
def band_from_wavelength(lam):
    """Return MIRI MRS band for a wavelength in µm."""
    lam = float(lam)
    # Channel 1
    if 4.90 <= lam <= 5.74:  return "1A"   # SHORT
    if 5.66 <= lam <= 6.63:  return "1B"   # MEDIUM
    if 6.53 <= lam <= 7.65:  return "1C"   # LONG

    # Channel 2
    if 7.51 <= lam <= 8.77:  return "2A"   # SHORT
    if 8.67 <= lam <= 10.13: return "2B"   # MEDIUM
    if 10.01 <= lam <= 11.70: return "2C"  # LONG

    # Channel 3
    if 11.55 <= lam <= 13.47: return "3A"  # SHORT
    if 13.34 <= lam <= 15.57: return "3B"  # MEDIUM
    if 15.41 <= lam <= 17.98: return "3C"  # LONG

    raise ValueError(f"Wavelength {lam} µm is outside MIRI MRS range")


def compute_matching_kernel(psf_native, psf_target, reg=1e-6):
    """
    Compute kernel K such that psf_native * K ≈ psf_target.
    Uses FFT deconvolution with a small regularisation.
    Both psf_native and psf_target must be 2D arrays of the same shape.
    Returns K (same shape) normalised to sum = 1.
    """
    # Ensure same shape; pad if necessary (here we assume they are same)
    if psf_native.shape != psf_target.shape:
        raise ValueError("PSFs must have the same shape")
    
    # FFT
    Fn = fft2(psf_native)
    Ft = fft2(psf_target)
    
    # Wiener deconvolution: K_hat = conj(Fn) * Ft / (|Fn|^2 + reg)
    # To avoid complex division, we compute the complex ratio directly with regularisation.
    denom = np.abs(Fn)**2 + reg
    K_hat = np.conj(Fn) * Ft / denom
    
    # Inverse FFT
    K = np.real(ifft2(K_hat))
    
    # Shift to centre (optional, but good for visualisation)
    K = fftshift(K)
    
    # Normalise to sum=1 (flux conservation)
    K /= K.sum()
    
    return K

def smooth_cube_to_target_psf(infile, outfile, target_wavelength=17.98):
    """
    Homogenise each slice to the PSF at target_wavelength.
    For each slice, compute the matching kernel via FFT deconvolution
    of the native PSF (at slice wavelength) and the target PSF.
    """
    # Read cube
    sc = SpectralCube.read(infile, hdu=1)
    flux = fits.getdata(infile, hdu=1)
    err  = fits.getdata(infile, hdu=2)
    sci_hdr = sc.header.copy()

    # Build wavelength array
    if all(k in sci_hdr for k in ["CRVAL3", "CDELT3", "CRPIX3"]):
        nlam = sci_hdr["NAXIS3"]
        lambdas = ((np.arange(nlam) - (sci_hdr["CRPIX3"] - 1)) *
                   sci_hdr["CDELT3"] + sci_hdr["CRVAL3"])
    else:
        raise ValueError("Spectral WCS keywords missing from header!")

    # Pixel scale in arcsec
    pixscale = sci_hdr["CDELT2"] * 3600.0

    # Allocate output arrays
    sm_flux = np.empty_like(flux)
    sm_err  = np.empty_like(err)

    # --- Pre‑compute target PSF (once) ---
    target_band = band_from_wavelength(target_wavelength)
    print(f"Computing target PSF at λ = {target_wavelength} µm (band {target_band})")
    miri_target = stpsf.MIRI()
    miri_target.mode = 'IFU'
    miri_target.band = target_band
    miri_target.pixelscale = pixscale
    psf_target_hdu = miri_target.calc_psf(monochromatic=target_wavelength * u.micron)
    psf_target = psf_target_hdu[1].data.astype(float)
    psf_target /= psf_target.sum()      # normalise

    # Loop over slices
    for i in range(nlam):
        lam = lambdas[i]
        band = band_from_wavelength(lam)

        print(f"Processing slice {i+1}/{nlam}: λ = {lam:.3f} µm, band = {band}")

        # --- Generate native PSF for this slice ---
        miri = stpsf.MIRI()
        miri.mode = 'IFU'
        miri.band = band
        miri.pixelscale = pixscale
        psf_native_hdu = miri.calc_psf(monochromatic=lam * u.micron)
        psf_native = psf_native_hdu[1].data.astype(float)
        psf_native /= psf_native.sum()   # normalise

        # --- Compute matching kernel ---
        # Ensure both PSFs are same size; if not, pad the smaller one.
        # Here we assume they are both generated with same pixel scale and FOV,
        # but stpsf may return different array sizes for different wavelengths.
        # We'll pad to the larger size.
        h1, w1 = psf_native.shape
        h2, w2 = psf_target.shape
        h = max(h1, h2)
        w = max(w1, w2)
        psf_native_pad = np.zeros((h, w))
        psf_target_pad = np.zeros((h, w))
        # Place PSFs at centre
        y1, x1 = (h - h1)//2, (w - w1)//2
        y2, x2 = (h - h2)//2, (w - w2)//2
        psf_native_pad[y1:y1+h1, x1:x1+w1] = psf_native
        psf_target_pad[y2:y2+h2, x2:x2+w2] = psf_target

        # Compute matching kernel
        kernel = compute_matching_kernel(psf_native_pad, psf_target_pad, reg=1e-6)

        # --- Convolve flux ---
        img = np.nan_to_num(flux[i], nan=0.0)
        valid_mask = (~np.isnan(flux[i])).astype(float)

        # Use FFT convolution (kernel is same size as padded PSFs, but may be larger than image).
        # We can crop kernel to a reasonable size (e.g., to the size of the larger PSF)
        # to speed up convolution. Here we simply use fftconvolve with mode='same'.
        sm_slice = fftconvolve(img, kernel, mode='same')
        sm_slice *= valid_mask
        sm_slice[valid_mask == 0] = np.nan
        sm_flux[i] = sm_slice

        # --- Propagate errors (variance) ---
        var = np.nan_to_num(err[i]**2, nan=0.0)
        kernel_sq = kernel**2
        kernel_sq /= kernel_sq.sum()     # normalise squared kernel
        #f I dont normalise this PAHFIT breaks! for line files we wont need this

        sm_var = fftconvolve(var, kernel_sq, mode='same')
        sm_var = np.clip(sm_var, 0, None)
        sm_err[i] = np.sqrt(sm_var)
        sm_err[i][valid_mask == 0] = np.nan

    # Write output FITS file
    primary = fits.PrimaryHDU()
    sci_hdu = fits.ImageHDU(data=sm_flux.astype(np.float32), header=sci_hdr, name='SCI')
    err_hdu = fits.ImageHDU(data=sm_err.astype(np.float32), header=sci_hdr.copy(), name='ERR')
    dq_hdu  = fits.ImageHDU(data=np.zeros_like(sm_flux, dtype=np.uint32),
                            header=sci_hdr.copy(), name='DQ')
    hdul = fits.HDUList([primary, sci_hdu, err_hdu, dq_hdu])
    hdul.writeto(outfile, overwrite=True)

    print(f"Wrote {outfile}, shape={sm_flux.shape}")


# -----------------------
# Example usage for 3 channels
# -----------------------
outdir = "./psf_smooth_cubes"
os.makedirs(outdir, exist_ok=True)

for ch in range(1, 4):
    infile = f"../../github/astr796_25_V2/files/NGC253_sky_v1_17_1_ch{ch}-shortmediumlong_s3d.fits"
    outfile = os.path.join(outdir, f"NGC253_sky_v1_17_1_ch{ch}-smooth.fits")
    smooth_cube_to_target_psf(infile, outfile, target_wavelength=17.98)
# Out:
# Computing target PSF at λ = 17.98 µm (band 3C)
# /Users/u826s018/miniconda3/envs/nearbygalaxies/lib/python3.11/site-packages/stpsf/opds.py:1759: UserWarning: For (V2,V3) = [-8.399315 -5.319645] arcmin, Field point -8.254199999999999 arcmin, -2.480355000000001 arcmin not within valid region for field dependence model of OTE WFE for MIRI: -8.254199999999999 arcmin--6.21738 arcmin, -2.557224 arcmin--0.5632056 arcmin.  Clipping to closest available valid location, 0.14511500000000055 arcmin away from the requested coordinates.
#   warnings.warn(warning_message)
# Processing slice 1/3438: λ = 4.900 µm, band = 1A
# /Users/u826s018/miniconda3/envs/nearbygalaxies/lib/python3.11/site-packages/stpsf/opds.py:1759: UserWarning: For (V2,V3) = [-8.38963333 -5.31665333] arcmin, Field point -8.254199999999999 arcmin, -2.4833466666666677 arcmin not within valid region for field dependence model of OTE WFE for MIRI: -8.254199999999999 arcmin--6.21738 arcmin, -2.557224 arcmin--0.5632056 arcmin.  Clipping to closest available valid location, 0.1354333333333333 arcmin away from the requested coordinates.
#   warnings.warn(warning_message)
# Processing slice 2/3438: λ = 4.901 µm, band = 1A
# Processing slice 3/3438: λ = 4.902 µm, band = 1A
# Processing slice 4/3438: λ = 4.903 µm, band = 1A
# Processing slice 5/3438: λ = 4.904 µm, band = 1A
# Processing slice 6/3438: λ = 4.904 µm, band = 1A
# Processing slice 7/3438: λ = 4.905 µm, band = 1A
# Processing slice 8/3438: λ = 4.906 µm, band = 1A
# Processing slice 9/3438: λ = 4.907 µm, band = 1A
# Processing slice 10/3438: λ = 4.908 µm, band = 1A
# Processing slice 11/3438: λ = 4.908 µm, band = 1A
# Processing slice 12/3438: λ = 4.909 µm, band = 1A
# Processing slice 13/3438: λ = 4.910 µm, band = 1A
# Processing slice 14/3438: λ = 4.911 µm, band = 1A
# Processing slice 15/3438: λ = 4.912 µm, band = 1A
# Processing slice 16/3438: λ = 4.912 µm, band = 1A
# Processing slice 17/3438: λ = 4.913 µm, band = 1A
# Processing slice 18/3438: λ = 4.914 µm, band = 1A
# Processing slice 19/3438: λ = 4.915 µm, band = 1A
# Processing slice 20/3438: λ = 4.916 µm, band = 1A
# Processing slice 21/3438: λ = 4.916 µm, band = 1A
# Processing slice 22/3438: λ = 4.917 µm, band = 1A
# Processing slice 23/3438: λ = 4.918 µm, band = 1A
# Processing slice 24/3438: λ = 4.919 µm, band = 1A
# Processing slice 25/3438: λ = 4.920 µm, band = 1A
# Processing slice 26/3438: λ = 4.920 µm, band = 1A
# Processing slice 27/3438: λ = 4.921 µm, band = 1A
# Processing slice 28/3438: λ = 4.922 µm, band = 1A
# Processing slice 29/3438: λ = 4.923 µm, band = 1A
# Processing slice 30/3438: λ = 4.924 µm, band = 1A
# Processing slice 31/3438: λ = 4.924 µm, band = 1A
# Processing slice 32/3438: λ = 4.925 µm, band = 1A
# Processing slice 33/3438: λ = 4.926 µm, band = 1A
# Processing slice 34/3438: λ = 4.927 µm, band = 1A
# Processing slice 35/3438: λ = 4.928 µm, band = 1A
# Processing slice 36/3438: λ = 4.928 µm, band = 1A
# Processing slice 37/3438: λ = 4.929 µm, band = 1A
# Processing slice 38/3438: λ = 4.930 µm, band = 1A
# Processing slice 39/3438: λ = 4.931 µm, band = 1A
# Processing slice 40/3438: λ = 4.932 µm, band = 1A
# Processing slice 41/3438: λ = 4.932 µm, band = 1A
# Processing slice 42/3438: λ = 4.933 µm, band = 1A
# Processing slice 43/3438: λ = 4.934 µm, band = 1A
# Processing slice 44/3438: λ = 4.935 µm, band = 1A
# Processing slice 45/3438: λ = 4.936 µm, band = 1A
# Processing slice 46/3438: λ = 4.936 µm, band = 1A
# Processing slice 47/3438: λ = 4.937 µm, band = 1A
# Processing slice 48/3438: λ = 4.938 µm, band = 1A
# Processing slice 49/3438: λ = 4.939 µm, band = 1A
# Processing slice 50/3438: λ = 4.940 µm, band = 1A
# Processing slice 51/3438: λ = 4.940 µm, band = 1A
# Processing slice 52/3438: λ = 4.941 µm, band = 1A
# Processing slice 53/3438: λ = 4.942 µm, band = 1A
# Processing slice 54/3438: λ = 4.943 µm, band = 1A
# Processing slice 55/3438: λ = 4.944 µm, band = 1A
# Processing slice 56/3438: λ = 4.944 µm, band = 1A
# Processing slice 57/3438: λ = 4.945 µm, band = 1A
# Processing slice 58/3438: λ = 4.946 µm, band = 1A
# Processing slice 59/3438: λ = 4.947 µm, band = 1A
# Processing slice 60/3438: λ = 4.948 µm, band = 1A
# Processing slice 61/3438: λ = 4.948 µm, band = 1A
# Processing slice 62/3438: λ = 4.949 µm, band = 1A
# Processing slice 63/3438: λ = 4.950 µm, band = 1A
# Processing slice 64/3438: λ = 4.951 µm, band = 1A
# Processing slice 65/3438: λ = 4.952 µm, band = 1A
# Processing slice 66/3438: λ = 4.952 µm, band = 1A
# Processing slice 67/3438: λ = 4.953 µm, band = 1A
# Processing slice 68/3438: λ = 4.954 µm, band = 1A
# Processing slice 69/3438: λ = 4.955 µm, band = 1A
# Processing slice 70/3438: λ = 4.956 µm, band = 1A
# Processing slice 71/3438: λ = 4.956 µm, band = 1A
# Processing slice 72/3438: λ = 4.957 µm, band = 1A
# Processing slice 73/3438: λ = 4.958 µm, band = 1A
# Processing slice 74/3438: λ = 4.959 µm, band = 1A
# Processing slice 75/3438: λ = 4.960 µm, band = 1A
# Processing slice 76/3438: λ = 4.960 µm, band = 1A
# Processing slice 77/3438: λ = 4.961 µm, band = 1A
# Processing slice 78/3438: λ = 4.962 µm, band = 1A
# Processing slice 79/3438: λ = 4.963 µm, band = 1A
# Processing slice 80/3438: λ = 4.964 µm, band = 1A
# Processing slice 81/3438: λ = 4.964 µm, band = 1A
# Processing slice 82/3438: λ = 4.965 µm, band = 1A
# Processing slice 83/3438: λ = 4.966 µm, band = 1A
# Processing slice 84/3438: λ = 4.967 µm, band = 1A
# Processing slice 85/3438: λ = 4.968 µm, band = 1A
# Processing slice 86/3438: λ = 4.968 µm, band = 1A
# Processing slice 87/3438: λ = 4.969 µm, band = 1A
# Processing slice 88/3438: λ = 4.970 µm, band = 1A
# Processing slice 89/3438: λ = 4.971 µm, band = 1A
# Processing slice 90/3438: λ = 4.972 µm, band = 1A
# Processing slice 91/3438: λ = 4.972 µm, band = 1A
# Processing slice 92/3438: λ = 4.973 µm, band = 1A
# Processing slice 93/3438: λ = 4.974 µm, band = 1A
# Processing slice 94/3438: λ = 4.975 µm, band = 1A
# Processing slice 95/3438: λ = 4.976 µm, band = 1A
# Processing slice 96/3438: λ = 4.976 µm, band = 1A
# Processing slice 97/3438: λ = 4.977 µm, band = 1A
# Processing slice 98/3438: λ = 4.978 µm, band = 1A
# Processing slice 99/3438: λ = 4.979 µm, band = 1A
# Processing slice 100/3438: λ = 4.980 µm, band = 1A
# Processing slice 101/3438: λ = 4.980 µm, band = 1A
# Processing slice 102/3438: λ = 4.981 µm, band = 1A
# Processing slice 103/3438: λ = 4.982 µm, band = 1A
# Processing slice 104/3438: λ = 4.983 µm, band = 1A
# Processing slice 105/3438: λ = 4.984 µm, band = 1A
# Processing slice 106/3438: λ = 4.984 µm, band = 1A
# Processing slice 107/3438: λ = 4.985 µm, band = 1A
# Processing slice 108/3438: λ = 4.986 µm, band = 1A
# Processing slice 109/3438: λ = 4.987 µm, band = 1A
# Processing slice 110/3438: λ = 4.988 µm, band = 1A
# Processing slice 111/3438: λ = 4.988 µm, band = 1A
# Processing slice 112/3438: λ = 4.989 µm, band = 1A
# Processing slice 113/3438: λ = 4.990 µm, band = 1A
# Processing slice 114/3438: λ = 4.991 µm, band = 1A
# Processing slice 115/3438: λ = 4.992 µm, band = 1A
# Processing slice 116/3438: λ = 4.992 µm, band = 1A
# Processing slice 117/3438: λ = 4.993 µm, band = 1A
# Processing slice 118/3438: λ = 4.994 µm, band = 1A
# Processing slice 119/3438: λ = 4.995 µm, band = 1A
# Processing slice 120/3438: λ = 4.996 µm, band = 1A
# Processing slice 121/3438: λ = 4.996 µm, band = 1A
# Processing slice 122/3438: λ = 4.997 µm, band = 1A
# Processing slice 123/3438: λ = 4.998 µm, band = 1A
# Processing slice 124/3438: λ = 4.999 µm, band = 1A
# Processing slice 125/3438: λ = 5.000 µm, band = 1A
# Processing slice 126/3438: λ = 5.000 µm, band = 1A
# Processing slice 127/3438: λ = 5.001 µm, band = 1A
# Processing slice 128/3438: λ = 5.002 µm, band = 1A
# Processing slice 129/3438: λ = 5.003 µm, band = 1A
# Processing slice 130/3438: λ = 5.004 µm, band = 1A
# Processing slice 131/3438: λ = 5.004 µm, band = 1A
# Processing slice 132/3438: λ = 5.005 µm, band = 1A
# Processing slice 133/3438: λ = 5.006 µm, band = 1A
# Processing slice 134/3438: λ = 5.007 µm, band = 1A
# Processing slice 135/3438: λ = 5.008 µm, band = 1A
# Processing slice 136/3438: λ = 5.008 µm, band = 1A
# Processing slice 137/3438: λ = 5.009 µm, band = 1A
# Processing slice 138/3438: λ = 5.010 µm, band = 1A
# Processing slice 139/3438: λ = 5.011 µm, band = 1A
# Processing slice 140/3438: λ = 5.012 µm, band = 1A
# Processing slice 141/3438: λ = 5.012 µm, band = 1A
# Processing slice 142/3438: λ = 5.013 µm, band = 1A
# Processing slice 143/3438: λ = 5.014 µm, band = 1A
# Processing slice 144/3438: λ = 5.015 µm, band = 1A
# Processing slice 145/3438: λ = 5.016 µm, band = 1A
# Processing slice 146/3438: λ = 5.016 µm, band = 1A
# Processing slice 147/3438: λ = 5.017 µm, band = 1A
# Processing slice 148/3438: λ = 5.018 µm, band = 1A
# Processing slice 149/3438: λ = 5.019 µm, band = 1A
# Processing slice 150/3438: λ = 5.020 µm, band = 1A
# Processing slice 151/3438: λ = 5.020 µm, band = 1A
# Processing slice 152/3438: λ = 5.021 µm, band = 1A
# Processing slice 153/3438: λ = 5.022 µm, band = 1A
# Processing slice 154/3438: λ = 5.023 µm, band = 1A
# Processing slice 155/3438: λ = 5.024 µm, band = 1A
# Processing slice 156/3438: λ = 5.024 µm, band = 1A
# Processing slice 157/3438: λ = 5.025 µm, band = 1A
# Processing slice 158/3438: λ = 5.026 µm, band = 1A
# Processing slice 159/3438: λ = 5.027 µm, band = 1A
# Processing slice 160/3438: λ = 5.028 µm, band = 1A
# Processing slice 161/3438: λ = 5.028 µm, band = 1A
# Processing slice 162/3438: λ = 5.029 µm, band = 1A
# Processing slice 163/3438: λ = 5.030 µm, band = 1A
# Processing slice 164/3438: λ = 5.031 µm, band = 1A
# Processing slice 165/3438: λ = 5.032 µm, band = 1A
# Processing slice 166/3438: λ = 5.032 µm, band = 1A
# Processing slice 167/3438: λ = 5.033 µm, band = 1A
# Processing slice 168/3438: λ = 5.034 µm, band = 1A
# Processing slice 169/3438: λ = 5.035 µm, band = 1A
# Processing slice 170/3438: λ = 5.036 µm, band = 1A
# Processing slice 171/3438: λ = 5.036 µm, band = 1A
# Processing slice 172/3438: λ = 5.037 µm, band = 1A
# Processing slice 173/3438: λ = 5.038 µm, band = 1A
# Processing slice 174/3438: λ = 5.039 µm, band = 1A
# Processing slice 175/3438: λ = 5.040 µm, band = 1A
# Processing slice 176/3438: λ = 5.040 µm, band = 1A
# Processing slice 177/3438: λ = 5.041 µm, band = 1A
# Processing slice 178/3438: λ = 5.042 µm, band = 1A
# Processing slice 179/3438: λ = 5.043 µm, band = 1A
# Processing slice 180/3438: λ = 5.044 µm, band = 1A
# Processing slice 181/3438: λ = 5.044 µm, band = 1A
# Processing slice 182/3438: λ = 5.045 µm, band = 1A
# Processing slice 183/3438: λ = 5.046 µm, band = 1A
# Processing slice 184/3438: λ = 5.047 µm, band = 1A
# Processing slice 185/3438: λ = 5.048 µm, band = 1A
# Processing slice 186/3438: λ = 5.048 µm, band = 1A
# Processing slice 187/3438: λ = 5.049 µm, band = 1A
# Processing slice 188/3438: λ = 5.050 µm, band = 1A
# Processing slice 189/3438: λ = 5.051 µm, band = 1A
# Processing slice 190/3438: λ = 5.052 µm, band = 1A
# Processing slice 191/3438: λ = 5.052 µm, band = 1A
# Processing slice 192/3438: λ = 5.053 µm, band = 1A
# Processing slice 193/3438: λ = 5.054 µm, band = 1A
# Processing slice 194/3438: λ = 5.055 µm, band = 1A
# Processing slice 195/3438: λ = 5.056 µm, band = 1A
# Processing slice 196/3438: λ = 5.056 µm, band = 1A
# Processing slice 197/3438: λ = 5.057 µm, band = 1A
# Processing slice 198/3438: λ = 5.058 µm, band = 1A
# Processing slice 199/3438: λ = 5.059 µm, band = 1A
# Processing slice 200/3438: λ = 5.060 µm, band = 1A
# Processing slice 201/3438: λ = 5.060 µm, band = 1A
# Processing slice 202/3438: λ = 5.061 µm, band = 1A
# Processing slice 203/3438: λ = 5.062 µm, band = 1A
# Processing slice 204/3438: λ = 5.063 µm, band = 1A
# Processing slice 205/3438: λ = 5.064 µm, band = 1A
# Processing slice 206/3438: λ = 5.064 µm, band = 1A
# Processing slice 207/3438: λ = 5.065 µm, band = 1A
# Processing slice 208/3438: λ = 5.066 µm, band = 1A
# Processing slice 209/3438: λ = 5.067 µm, band = 1A
# Processing slice 210/3438: λ = 5.068 µm, band = 1A
# Processing slice 211/3438: λ = 5.068 µm, band = 1A
# Processing slice 212/3438: λ = 5.069 µm, band = 1A
# Processing slice 213/3438: λ = 5.070 µm, band = 1A
# Processing slice 214/3438: λ = 5.071 µm, band = 1A
# Processing slice 215/3438: λ = 5.072 µm, band = 1A
# Processing slice 216/3438: λ = 5.072 µm, band = 1A
# Processing slice 217/3438: λ = 5.073 µm, band = 1A
# Processing slice 218/3438: λ = 5.074 µm, band = 1A
# Processing slice 219/3438: λ = 5.075 µm, band = 1A
# Processing slice 220/3438: λ = 5.076 µm, band = 1A
# Processing slice 221/3438: λ = 5.076 µm, band = 1A
# Processing slice 222/3438: λ = 5.077 µm, band = 1A
# Processing slice 223/3438: λ = 5.078 µm, band = 1A
# Processing slice 224/3438: λ = 5.079 µm, band = 1A
# Processing slice 225/3438: λ = 5.080 µm, band = 1A
# Processing slice 226/3438: λ = 5.080 µm, band = 1A
# Processing slice 227/3438: λ = 5.081 µm, band = 1A
# Processing slice 228/3438: λ = 5.082 µm, band = 1A
# Processing slice 229/3438: λ = 5.083 µm, band = 1A
# Processing slice 230/3438: λ = 5.084 µm, band = 1A
# Processing slice 231/3438: λ = 5.084 µm, band = 1A
# Processing slice 232/3438: λ = 5.085 µm, band = 1A
# Processing slice 233/3438: λ = 5.086 µm, band = 1A
# Processing slice 234/3438: λ = 5.087 µm, band = 1A
# Processing slice 235/3438: λ = 5.088 µm, band = 1A
# Processing slice 236/3438: λ = 5.088 µm, band = 1A
# Processing slice 237/3438: λ = 5.089 µm, band = 1A
# Processing slice 238/3438: λ = 5.090 µm, band = 1A
# Processing slice 239/3438: λ = 5.091 µm, band = 1A
# Processing slice 240/3438: λ = 5.092 µm, band = 1A
# Processing slice 241/3438: λ = 5.092 µm, band = 1A
# Processing slice 242/3438: λ = 5.093 µm, band = 1A
# Processing slice 243/3438: λ = 5.094 µm, band = 1A
# Processing slice 244/3438: λ = 5.095 µm, band = 1A
# Processing slice 245/3438: λ = 5.096 µm, band = 1A
# Processing slice 246/3438: λ = 5.096 µm, band = 1A
# Processing slice 247/3438: λ = 5.097 µm, band = 1A
# Processing slice 248/3438: λ = 5.098 µm, band = 1A
# Processing slice 249/3438: λ = 5.099 µm, band = 1A
# Processing slice 250/3438: λ = 5.100 µm, band = 1A
# Processing slice 251/3438: λ = 5.100 µm, band = 1A
# Processing slice 252/3438: λ = 5.101 µm, band = 1A
# Processing slice 253/3438: λ = 5.102 µm, band = 1A
# Processing slice 254/3438: λ = 5.103 µm, band = 1A
# Processing slice 255/3438: λ = 5.104 µm, band = 1A
# Processing slice 256/3438: λ = 5.104 µm, band = 1A
# Processing slice 257/3438: λ = 5.105 µm, band = 1A
# Processing slice 258/3438: λ = 5.106 µm, band = 1A
# Processing slice 259/3438: λ = 5.107 µm, band = 1A
# Processing slice 260/3438: λ = 5.108 µm, band = 1A
# Processing slice 261/3438: λ = 5.108 µm, band = 1A
# Processing slice 262/3438: λ = 5.109 µm, band = 1A
# Processing slice 263/3438: λ = 5.110 µm, band = 1A
# Processing slice 264/3438: λ = 5.111 µm, band = 1A
# Processing slice 265/3438: λ = 5.112 µm, band = 1A
# Processing slice 266/3438: λ = 5.112 µm, band = 1A
# Processing slice 267/3438: λ = 5.113 µm, band = 1A
# Processing slice 268/3438: λ = 5.114 µm, band = 1A
# Processing slice 269/3438: λ = 5.115 µm, band = 1A
# Processing slice 270/3438: λ = 5.116 µm, band = 1A
# Processing slice 271/3438: λ = 5.116 µm, band = 1A
# Processing slice 272/3438: λ = 5.117 µm, band = 1A
# Processing slice 273/3438: λ = 5.118 µm, band = 1A
# Processing slice 274/3438: λ = 5.119 µm, band = 1A
# Processing slice 275/3438: λ = 5.120 µm, band = 1A
# Processing slice 276/3438: λ = 5.120 µm, band = 1A
# Processing slice 277/3438: λ = 5.121 µm, band = 1A
# Processing slice 278/3438: λ = 5.122 µm, band = 1A
# Processing slice 279/3438: λ = 5.123 µm, band = 1A
# Processing slice 280/3438: λ = 5.124 µm, band = 1A
# Processing slice 281/3438: λ = 5.124 µm, band = 1A
# Processing slice 282/3438: λ = 5.125 µm, band = 1A
# Processing slice 283/3438: λ = 5.126 µm, band = 1A
# Processing slice 284/3438: λ = 5.127 µm, band = 1A
# Processing slice 285/3438: λ = 5.128 µm, band = 1A
# Processing slice 286/3438: λ = 5.128 µm, band = 1A
# Processing slice 287/3438: λ = 5.129 µm, band = 1A
# Processing slice 288/3438: λ = 5.130 µm, band = 1A
# Processing slice 289/3438: λ = 5.131 µm, band = 1A
# Processing slice 290/3438: λ = 5.132 µm, band = 1A
# Processing slice 291/3438: λ = 5.132 µm, band = 1A
# Processing slice 292/3438: λ = 5.133 µm, band = 1A
# Processing slice 293/3438: λ = 5.134 µm, band = 1A
# Processing slice 294/3438: λ = 5.135 µm, band = 1A
# Processing slice 295/3438: λ = 5.136 µm, band = 1A
# Processing slice 296/3438: λ = 5.136 µm, band = 1A
# Processing slice 297/3438: λ = 5.137 µm, band = 1A
# Processing slice 298/3438: λ = 5.138 µm, band = 1A
# Processing slice 299/3438: λ = 5.139 µm, band = 1A
# Processing slice 300/3438: λ = 5.140 µm, band = 1A
# Processing slice 301/3438: λ = 5.140 µm, band = 1A
# Processing slice 302/3438: λ = 5.141 µm, band = 1A
# Processing slice 303/3438: λ = 5.142 µm, band = 1A
# Processing slice 304/3438: λ = 5.143 µm, band = 1A
# Processing slice 305/3438: λ = 5.144 µm, band = 1A
# Processing slice 306/3438: λ = 5.144 µm, band = 1A
# Processing slice 307/3438: λ = 5.145 µm, band = 1A
# Processing slice 308/3438: λ = 5.146 µm, band = 1A
# Processing slice 309/3438: λ = 5.147 µm, band = 1A
# Processing slice 310/3438: λ = 5.148 µm, band = 1A
# Processing slice 311/3438: λ = 5.148 µm, band = 1A
# Processing slice 312/3438: λ = 5.149 µm, band = 1A
# Processing slice 313/3438: λ = 5.150 µm, band = 1A
# Processing slice 314/3438: λ = 5.151 µm, band = 1A
# Processing slice 315/3438: λ = 5.152 µm, band = 1A
# Processing slice 316/3438: λ = 5.152 µm, band = 1A
# Processing slice 317/3438: λ = 5.153 µm, band = 1A
# Processing slice 318/3438: λ = 5.154 µm, band = 1A
# Processing slice 319/3438: λ = 5.155 µm, band = 1A
# Processing slice 320/3438: λ = 5.156 µm, band = 1A
# Processing slice 321/3438: λ = 5.156 µm, band = 1A
# Processing slice 322/3438: λ = 5.157 µm, band = 1A
# Processing slice 323/3438: λ = 5.158 µm, band = 1A
# Processing slice 324/3438: λ = 5.159 µm, band = 1A
# Processing slice 325/3438: λ = 5.160 µm, band = 1A
# Processing slice 326/3438: λ = 5.160 µm, band = 1A
# Processing slice 327/3438: λ = 5.161 µm, band = 1A
# Processing slice 328/3438: λ = 5.162 µm, band = 1A
# Processing slice 329/3438: λ = 5.163 µm, band = 1A
# Processing slice 330/3438: λ = 5.164 µm, band = 1A
# Processing slice 331/3438: λ = 5.164 µm, band = 1A
# Processing slice 332/3438: λ = 5.165 µm, band = 1A
# Processing slice 333/3438: λ = 5.166 µm, band = 1A
# Processing slice 334/3438: λ = 5.167 µm, band = 1A
# Processing slice 335/3438: λ = 5.168 µm, band = 1A
# Processing slice 336/3438: λ = 5.168 µm, band = 1A
# Processing slice 337/3438: λ = 5.169 µm, band = 1A
# Processing slice 338/3438: λ = 5.170 µm, band = 1A
# Processing slice 339/3438: λ = 5.171 µm, band = 1A
# Processing slice 340/3438: λ = 5.172 µm, band = 1A
# Processing slice 341/3438: λ = 5.172 µm, band = 1A
# Processing slice 342/3438: λ = 5.173 µm, band = 1A
# Processing slice 343/3438: λ = 5.174 µm, band = 1A
# Processing slice 344/3438: λ = 5.175 µm, band = 1A
# Processing slice 345/3438: λ = 5.176 µm, band = 1A
# Processing slice 346/3438: λ = 5.176 µm, band = 1A
# Processing slice 347/3438: λ = 5.177 µm, band = 1A
# Processing slice 348/3438: λ = 5.178 µm, band = 1A
# Processing slice 349/3438: λ = 5.179 µm, band = 1A
# Processing slice 350/3438: λ = 5.180 µm, band = 1A
# Processing slice 351/3438: λ = 5.180 µm, band = 1A
# Processing slice 352/3438: λ = 5.181 µm, band = 1A
# Processing slice 353/3438: λ = 5.182 µm, band = 1A
# Processing slice 354/3438: λ = 5.183 µm, band = 1A
# Processing slice 355/3438: λ = 5.184 µm, band = 1A
# Processing slice 356/3438: λ = 5.184 µm, band = 1A
# Processing slice 357/3438: λ = 5.185 µm, band = 1A
# Processing slice 358/3438: λ = 5.186 µm, band = 1A
# Processing slice 359/3438: λ = 5.187 µm, band = 1A
# Processing slice 360/3438: λ = 5.188 µm, band = 1A
# Processing slice 361/3438: λ = 5.188 µm, band = 1A
# Processing slice 362/3438: λ = 5.189 µm, band = 1A
# Processing slice 363/3438: λ = 5.190 µm, band = 1A
# Processing slice 364/3438: λ = 5.191 µm, band = 1A
# Processing slice 365/3438: λ = 5.192 µm, band = 1A
# Processing slice 366/3438: λ = 5.192 µm, band = 1A
# Processing slice 367/3438: λ = 5.193 µm, band = 1A
# Processing slice 368/3438: λ = 5.194 µm, band = 1A
# Processing slice 369/3438: λ = 5.195 µm, band = 1A
# Processing slice 370/3438: λ = 5.196 µm, band = 1A
# Processing slice 371/3438: λ = 5.196 µm, band = 1A
# Processing slice 372/3438: λ = 5.197 µm, band = 1A
# Processing slice 373/3438: λ = 5.198 µm, band = 1A
# Processing slice 374/3438: λ = 5.199 µm, band = 1A
# Processing slice 375/3438: λ = 5.200 µm, band = 1A
# Processing slice 376/3438: λ = 5.200 µm, band = 1A
# Processing slice 377/3438: λ = 5.201 µm, band = 1A
# Processing slice 378/3438: λ = 5.202 µm, band = 1A
# Processing slice 379/3438: λ = 5.203 µm, band = 1A
# Processing slice 380/3438: λ = 5.204 µm, band = 1A
# Processing slice 381/3438: λ = 5.204 µm, band = 1A
# Processing slice 382/3438: λ = 5.205 µm, band = 1A
# Processing slice 383/3438: λ = 5.206 µm, band = 1A
# Processing slice 384/3438: λ = 5.207 µm, band = 1A
# Processing slice 385/3438: λ = 5.208 µm, band = 1A
# Processing slice 386/3438: λ = 5.208 µm, band = 1A
# Processing slice 387/3438: λ = 5.209 µm, band = 1A
# Processing slice 388/3438: λ = 5.210 µm, band = 1A
# Processing slice 389/3438: λ = 5.211 µm, band = 1A
# Processing slice 390/3438: λ = 5.212 µm, band = 1A
# Processing slice 391/3438: λ = 5.212 µm, band = 1A
# Processing slice 392/3438: λ = 5.213 µm, band = 1A
# Processing slice 393/3438: λ = 5.214 µm, band = 1A
# Processing slice 394/3438: λ = 5.215 µm, band = 1A
# Processing slice 395/3438: λ = 5.216 µm, band = 1A
# Processing slice 396/3438: λ = 5.216 µm, band = 1A
# Processing slice 397/3438: λ = 5.217 µm, band = 1A
# Processing slice 398/3438: λ = 5.218 µm, band = 1A
# Processing slice 399/3438: λ = 5.219 µm, band = 1A
# Processing slice 400/3438: λ = 5.220 µm, band = 1A
# Processing slice 401/3438: λ = 5.220 µm, band = 1A
# Processing slice 402/3438: λ = 5.221 µm, band = 1A
# Processing slice 403/3438: λ = 5.222 µm, band = 1A
# Processing slice 404/3438: λ = 5.223 µm, band = 1A
# Processing slice 405/3438: λ = 5.224 µm, band = 1A
# Processing slice 406/3438: λ = 5.224 µm, band = 1A
# Processing slice 407/3438: λ = 5.225 µm, band = 1A
# Processing slice 408/3438: λ = 5.226 µm, band = 1A
# Processing slice 409/3438: λ = 5.227 µm, band = 1A
# Processing slice 410/3438: λ = 5.228 µm, band = 1A
# Processing slice 411/3438: λ = 5.228 µm, band = 1A
# Processing slice 412/3438: λ = 5.229 µm, band = 1A
# Processing slice 413/3438: λ = 5.230 µm, band = 1A
# Processing slice 414/3438: λ = 5.231 µm, band = 1A
# Processing slice 415/3438: λ = 5.232 µm, band = 1A
# Processing slice 416/3438: λ = 5.232 µm, band = 1A
# Processing slice 417/3438: λ = 5.233 µm, band = 1A
# Processing slice 418/3438: λ = 5.234 µm, band = 1A
# Processing slice 419/3438: λ = 5.235 µm, band = 1A
# Processing slice 420/3438: λ = 5.236 µm, band = 1A
# Processing slice 421/3438: λ = 5.236 µm, band = 1A
# Processing slice 422/3438: λ = 5.237 µm, band = 1A
# Processing slice 423/3438: λ = 5.238 µm, band = 1A
# Processing slice 424/3438: λ = 5.239 µm, band = 1A
# Processing slice 425/3438: λ = 5.240 µm, band = 1A
# Processing slice 426/3438: λ = 5.240 µm, band = 1A
# Processing slice 427/3438: λ = 5.241 µm, band = 1A
# Processing slice 428/3438: λ = 5.242 µm, band = 1A
# Processing slice 429/3438: λ = 5.243 µm, band = 1A
# Processing slice 430/3438: λ = 5.244 µm, band = 1A
# Processing slice 431/3438: λ = 5.244 µm, band = 1A
# Processing slice 432/3438: λ = 5.245 µm, band = 1A
# Processing slice 433/3438: λ = 5.246 µm, band = 1A
# Processing slice 434/3438: λ = 5.247 µm, band = 1A
# Processing slice 435/3438: λ = 5.248 µm, band = 1A
# Processing slice 436/3438: λ = 5.248 µm, band = 1A
# Processing slice 437/3438: λ = 5.249 µm, band = 1A
# Processing slice 438/3438: λ = 5.250 µm, band = 1A
# Processing slice 439/3438: λ = 5.251 µm, band = 1A
# Processing slice 440/3438: λ = 5.252 µm, band = 1A
# Processing slice 441/3438: λ = 5.252 µm, band = 1A
# Processing slice 442/3438: λ = 5.253 µm, band = 1A
# Processing slice 443/3438: λ = 5.254 µm, band = 1A
# Processing slice 444/3438: λ = 5.255 µm, band = 1A
# Processing slice 445/3438: λ = 5.256 µm, band = 1A
# Processing slice 446/3438: λ = 5.256 µm, band = 1A
# Processing slice 447/3438: λ = 5.257 µm, band = 1A
# Processing slice 448/3438: λ = 5.258 µm, band = 1A
# Processing slice 449/3438: λ = 5.259 µm, band = 1A
# Processing slice 450/3438: λ = 5.260 µm, band = 1A
# Processing slice 451/3438: λ = 5.260 µm, band = 1A
# Processing slice 452/3438: λ = 5.261 µm, band = 1A
# Processing slice 453/3438: λ = 5.262 µm, band = 1A
# Processing slice 454/3438: λ = 5.263 µm, band = 1A
# Processing slice 455/3438: λ = 5.264 µm, band = 1A
# Processing slice 456/3438: λ = 5.264 µm, band = 1A
# Processing slice 457/3438: λ = 5.265 µm, band = 1A
# Processing slice 458/3438: λ = 5.266 µm, band = 1A
# Processing slice 459/3438: λ = 5.267 µm, band = 1A
# Processing slice 460/3438: λ = 5.268 µm, band = 1A
# Processing slice 461/3438: λ = 5.268 µm, band = 1A
# Processing slice 462/3438: λ = 5.269 µm, band = 1A
# Processing slice 463/3438: λ = 5.270 µm, band = 1A
# Processing slice 464/3438: λ = 5.271 µm, band = 1A
# Processing slice 465/3438: λ = 5.272 µm, band = 1A
# Processing slice 466/3438: λ = 5.272 µm, band = 1A
# Processing slice 467/3438: λ = 5.273 µm, band = 1A
# Processing slice 468/3438: λ = 5.274 µm, band = 1A
# Processing slice 469/3438: λ = 5.275 µm, band = 1A
# Processing slice 470/3438: λ = 5.276 µm, band = 1A
# Processing slice 471/3438: λ = 5.276 µm, band = 1A
# Processing slice 472/3438: λ = 5.277 µm, band = 1A
# Processing slice 473/3438: λ = 5.278 µm, band = 1A
# Processing slice 474/3438: λ = 5.279 µm, band = 1A
# Processing slice 475/3438: λ = 5.280 µm, band = 1A
# Processing slice 476/3438: λ = 5.280 µm, band = 1A
# Processing slice 477/3438: λ = 5.281 µm, band = 1A
# Processing slice 478/3438: λ = 5.282 µm, band = 1A
# Processing slice 479/3438: λ = 5.283 µm, band = 1A
# Processing slice 480/3438: λ = 5.284 µm, band = 1A
# Processing slice 481/3438: λ = 5.284 µm, band = 1A
# Processing slice 482/3438: λ = 5.285 µm, band = 1A
# Processing slice 483/3438: λ = 5.286 µm, band = 1A
# Processing slice 484/3438: λ = 5.287 µm, band = 1A
# Processing slice 485/3438: λ = 5.288 µm, band = 1A
# Processing slice 486/3438: λ = 5.288 µm, band = 1A
# Processing slice 487/3438: λ = 5.289 µm, band = 1A
# Processing slice 488/3438: λ = 5.290 µm, band = 1A
# Processing slice 489/3438: λ = 5.291 µm, band = 1A
# Processing slice 490/3438: λ = 5.292 µm, band = 1A
# Processing slice 491/3438: λ = 5.292 µm, band = 1A
# Processing slice 492/3438: λ = 5.293 µm, band = 1A
# Processing slice 493/3438: λ = 5.294 µm, band = 1A
# Processing slice 494/3438: λ = 5.295 µm, band = 1A
# Processing slice 495/3438: λ = 5.296 µm, band = 1A
# Processing slice 496/3438: λ = 5.296 µm, band = 1A
# Processing slice 497/3438: λ = 5.297 µm, band = 1A
# Processing slice 498/3438: λ = 5.298 µm, band = 1A
# Processing slice 499/3438: λ = 5.299 µm, band = 1A
# Processing slice 500/3438: λ = 5.300 µm, band = 1A
# Processing slice 501/3438: λ = 5.300 µm, band = 1A
# Processing slice 502/3438: λ = 5.301 µm, band = 1A
# Processing slice 503/3438: λ = 5.302 µm, band = 1A
# Processing slice 504/3438: λ = 5.303 µm, band = 1A
# Processing slice 505/3438: λ = 5.304 µm, band = 1A
# Processing slice 506/3438: λ = 5.304 µm, band = 1A
# Processing slice 507/3438: λ = 5.305 µm, band = 1A
# Processing slice 508/3438: λ = 5.306 µm, band = 1A
# Processing slice 509/3438: λ = 5.307 µm, band = 1A
# Processing slice 510/3438: λ = 5.308 µm, band = 1A
# Processing slice 511/3438: λ = 5.308 µm, band = 1A
# Processing slice 512/3438: λ = 5.309 µm, band = 1A
# Processing slice 513/3438: λ = 5.310 µm, band = 1A
# Processing slice 514/3438: λ = 5.311 µm, band = 1A
# Processing slice 515/3438: λ = 5.312 µm, band = 1A
# Processing slice 516/3438: λ = 5.312 µm, band = 1A
# Processing slice 517/3438: λ = 5.313 µm, band = 1A
# Processing slice 518/3438: λ = 5.314 µm, band = 1A
# Processing slice 519/3438: λ = 5.315 µm, band = 1A
# Processing slice 520/3438: λ = 5.316 µm, band = 1A
# Processing slice 521/3438: λ = 5.316 µm, band = 1A
# Processing slice 522/3438: λ = 5.317 µm, band = 1A
# Processing slice 523/3438: λ = 5.318 µm, band = 1A
# Processing slice 524/3438: λ = 5.319 µm, band = 1A
# Processing slice 525/3438: λ = 5.320 µm, band = 1A
# Processing slice 526/3438: λ = 5.320 µm, band = 1A
# Processing slice 527/3438: λ = 5.321 µm, band = 1A
# Processing slice 528/3438: λ = 5.322 µm, band = 1A
# Processing slice 529/3438: λ = 5.323 µm, band = 1A
# Processing slice 530/3438: λ = 5.324 µm, band = 1A
# Processing slice 531/3438: λ = 5.324 µm, band = 1A
# Processing slice 532/3438: λ = 5.325 µm, band = 1A
# Processing slice 533/3438: λ = 5.326 µm, band = 1A
# Processing slice 534/3438: λ = 5.327 µm, band = 1A
# Processing slice 535/3438: λ = 5.328 µm, band = 1A
# Processing slice 536/3438: λ = 5.328 µm, band = 1A
# Processing slice 537/3438: λ = 5.329 µm, band = 1A
# Processing slice 538/3438: λ = 5.330 µm, band = 1A
# Processing slice 539/3438: λ = 5.331 µm, band = 1A
# Processing slice 540/3438: λ = 5.332 µm, band = 1A
# Processing slice 541/3438: λ = 5.332 µm, band = 1A
# Processing slice 542/3438: λ = 5.333 µm, band = 1A
# Processing slice 543/3438: λ = 5.334 µm, band = 1A
# Processing slice 544/3438: λ = 5.335 µm, band = 1A
# Processing slice 545/3438: λ = 5.336 µm, band = 1A
# Processing slice 546/3438: λ = 5.336 µm, band = 1A
# Processing slice 547/3438: λ = 5.337 µm, band = 1A
# Processing slice 548/3438: λ = 5.338 µm, band = 1A
# Processing slice 549/3438: λ = 5.339 µm, band = 1A
# Processing slice 550/3438: λ = 5.340 µm, band = 1A
# Processing slice 551/3438: λ = 5.340 µm, band = 1A
# Processing slice 552/3438: λ = 5.341 µm, band = 1A
# Processing slice 553/3438: λ = 5.342 µm, band = 1A
# Processing slice 554/3438: λ = 5.343 µm, band = 1A
# Processing slice 555/3438: λ = 5.344 µm, band = 1A
# Processing slice 556/3438: λ = 5.344 µm, band = 1A
# Processing slice 557/3438: λ = 5.345 µm, band = 1A
# Processing slice 558/3438: λ = 5.346 µm, band = 1A
# Processing slice 559/3438: λ = 5.347 µm, band = 1A
# Processing slice 560/3438: λ = 5.348 µm, band = 1A
# Processing slice 561/3438: λ = 5.348 µm, band = 1A
# Processing slice 562/3438: λ = 5.349 µm, band = 1A
# Processing slice 563/3438: λ = 5.350 µm, band = 1A
# Processing slice 564/3438: λ = 5.351 µm, band = 1A
# Processing slice 565/3438: λ = 5.352 µm, band = 1A
# Processing slice 566/3438: λ = 5.352 µm, band = 1A
# Processing slice 567/3438: λ = 5.353 µm, band = 1A
# Processing slice 568/3438: λ = 5.354 µm, band = 1A
# Processing slice 569/3438: λ = 5.355 µm, band = 1A
# Processing slice 570/3438: λ = 5.356 µm, band = 1A
# Processing slice 571/3438: λ = 5.356 µm, band = 1A
# Processing slice 572/3438: λ = 5.357 µm, band = 1A
# Processing slice 573/3438: λ = 5.358 µm, band = 1A
# Processing slice 574/3438: λ = 5.359 µm, band = 1A
# Processing slice 575/3438: λ = 5.360 µm, band = 1A
# Processing slice 576/3438: λ = 5.360 µm, band = 1A
# Processing slice 577/3438: λ = 5.361 µm, band = 1A
# Processing slice 578/3438: λ = 5.362 µm, band = 1A
# Processing slice 579/3438: λ = 5.363 µm, band = 1A
# Processing slice 580/3438: λ = 5.364 µm, band = 1A
# Processing slice 581/3438: λ = 5.364 µm, band = 1A
# Processing slice 582/3438: λ = 5.365 µm, band = 1A
# Processing slice 583/3438: λ = 5.366 µm, band = 1A
# Processing slice 584/3438: λ = 5.367 µm, band = 1A
# Processing slice 585/3438: λ = 5.368 µm, band = 1A
# Processing slice 586/3438: λ = 5.368 µm, band = 1A
# Processing slice 587/3438: λ = 5.369 µm, band = 1A
# Processing slice 588/3438: λ = 5.370 µm, band = 1A
# Processing slice 589/3438: λ = 5.371 µm, band = 1A
# Processing slice 590/3438: λ = 5.372 µm, band = 1A
# Processing slice 591/3438: λ = 5.372 µm, band = 1A
# Processing slice 592/3438: λ = 5.373 µm, band = 1A
# Processing slice 593/3438: λ = 5.374 µm, band = 1A
# Processing slice 594/3438: λ = 5.375 µm, band = 1A
# Processing slice 595/3438: λ = 5.376 µm, band = 1A
# Processing slice 596/3438: λ = 5.376 µm, band = 1A
# Processing slice 597/3438: λ = 5.377 µm, band = 1A
# Processing slice 598/3438: λ = 5.378 µm, band = 1A
# Processing slice 599/3438: λ = 5.379 µm, band = 1A
# Processing slice 600/3438: λ = 5.380 µm, band = 1A
# Processing slice 601/3438: λ = 5.380 µm, band = 1A
# Processing slice 602/3438: λ = 5.381 µm, band = 1A
# Processing slice 603/3438: λ = 5.382 µm, band = 1A
# Processing slice 604/3438: λ = 5.383 µm, band = 1A
# Processing slice 605/3438: λ = 5.384 µm, band = 1A
# Processing slice 606/3438: λ = 5.384 µm, band = 1A
# Processing slice 607/3438: λ = 5.385 µm, band = 1A
# Processing slice 608/3438: λ = 5.386 µm, band = 1A
# Processing slice 609/3438: λ = 5.387 µm, band = 1A
# Processing slice 610/3438: λ = 5.388 µm, band = 1A
# Processing slice 611/3438: λ = 5.388 µm, band = 1A
# Processing slice 612/3438: λ = 5.389 µm, band = 1A
# Processing slice 613/3438: λ = 5.390 µm, band = 1A
# Processing slice 614/3438: λ = 5.391 µm, band = 1A
# Processing slice 615/3438: λ = 5.392 µm, band = 1A
# Processing slice 616/3438: λ = 5.392 µm, band = 1A
# Processing slice 617/3438: λ = 5.393 µm, band = 1A
# Processing slice 618/3438: λ = 5.394 µm, band = 1A
# Processing slice 619/3438: λ = 5.395 µm, band = 1A
# Processing slice 620/3438: λ = 5.396 µm, band = 1A
# Processing slice 621/3438: λ = 5.396 µm, band = 1A
# Processing slice 622/3438: λ = 5.397 µm, band = 1A
# Processing slice 623/3438: λ = 5.398 µm, band = 1A
# Processing slice 624/3438: λ = 5.399 µm, band = 1A
# Processing slice 625/3438: λ = 5.400 µm, band = 1A
# Processing slice 626/3438: λ = 5.400 µm, band = 1A
# Processing slice 627/3438: λ = 5.401 µm, band = 1A
# Processing slice 628/3438: λ = 5.402 µm, band = 1A
# Processing slice 629/3438: λ = 5.403 µm, band = 1A
# Processing slice 630/3438: λ = 5.404 µm, band = 1A
# Processing slice 631/3438: λ = 5.404 µm, band = 1A
# Processing slice 632/3438: λ = 5.405 µm, band = 1A
# Processing slice 633/3438: λ = 5.406 µm, band = 1A
# Processing slice 634/3438: λ = 5.407 µm, band = 1A
# Processing slice 635/3438: λ = 5.408 µm, band = 1A
# Processing slice 636/3438: λ = 5.408 µm, band = 1A
# Processing slice 637/3438: λ = 5.409 µm, band = 1A
# Processing slice 638/3438: λ = 5.410 µm, band = 1A
# Processing slice 639/3438: λ = 5.411 µm, band = 1A
# Processing slice 640/3438: λ = 5.412 µm, band = 1A
# Processing slice 641/3438: λ = 5.412 µm, band = 1A
# Processing slice 642/3438: λ = 5.413 µm, band = 1A
# Processing slice 643/3438: λ = 5.414 µm, band = 1A
# Processing slice 644/3438: λ = 5.415 µm, band = 1A
# Processing slice 645/3438: λ = 5.416 µm, band = 1A
# Processing slice 646/3438: λ = 5.416 µm, band = 1A
# Processing slice 647/3438: λ = 5.417 µm, band = 1A
# Processing slice 648/3438: λ = 5.418 µm, band = 1A
# Processing slice 649/3438: λ = 5.419 µm, band = 1A
# Processing slice 650/3438: λ = 5.420 µm, band = 1A
# Processing slice 651/3438: λ = 5.420 µm, band = 1A
# Processing slice 652/3438: λ = 5.421 µm, band = 1A
# Processing slice 653/3438: λ = 5.422 µm, band = 1A
# Processing slice 654/3438: λ = 5.423 µm, band = 1A
# Processing slice 655/3438: λ = 5.424 µm, band = 1A
# Processing slice 656/3438: λ = 5.424 µm, band = 1A
# Processing slice 657/3438: λ = 5.425 µm, band = 1A
# Processing slice 658/3438: λ = 5.426 µm, band = 1A
# Processing slice 659/3438: λ = 5.427 µm, band = 1A
# Processing slice 660/3438: λ = 5.428 µm, band = 1A
# Processing slice 661/3438: λ = 5.428 µm, band = 1A
# Processing slice 662/3438: λ = 5.429 µm, band = 1A
# Processing slice 663/3438: λ = 5.430 µm, band = 1A
# Processing slice 664/3438: λ = 5.431 µm, band = 1A
# Processing slice 665/3438: λ = 5.432 µm, band = 1A
# Processing slice 666/3438: λ = 5.432 µm, band = 1A
# Processing slice 667/3438: λ = 5.433 µm, band = 1A
# Processing slice 668/3438: λ = 5.434 µm, band = 1A
# Processing slice 669/3438: λ = 5.435 µm, band = 1A
# Processing slice 670/3438: λ = 5.436 µm, band = 1A
# Processing slice 671/3438: λ = 5.436 µm, band = 1A
# Processing slice 672/3438: λ = 5.437 µm, band = 1A
# Processing slice 673/3438: λ = 5.438 µm, band = 1A
# Processing slice 674/3438: λ = 5.439 µm, band = 1A
# Processing slice 675/3438: λ = 5.440 µm, band = 1A
# Processing slice 676/3438: λ = 5.440 µm, band = 1A
# Processing slice 677/3438: λ = 5.441 µm, band = 1A
# Processing slice 678/3438: λ = 5.442 µm, band = 1A
# Processing slice 679/3438: λ = 5.443 µm, band = 1A
# Processing slice 680/3438: λ = 5.444 µm, band = 1A
# Processing slice 681/3438: λ = 5.444 µm, band = 1A
# Processing slice 682/3438: λ = 5.445 µm, band = 1A
# Processing slice 683/3438: λ = 5.446 µm, band = 1A
# Processing slice 684/3438: λ = 5.447 µm, band = 1A
# Processing slice 685/3438: λ = 5.448 µm, band = 1A
# Processing slice 686/3438: λ = 5.448 µm, band = 1A
# Processing slice 687/3438: λ = 5.449 µm, band = 1A
# Processing slice 688/3438: λ = 5.450 µm, band = 1A
# Processing slice 689/3438: λ = 5.451 µm, band = 1A
# Processing slice 690/3438: λ = 5.452 µm, band = 1A
# Processing slice 691/3438: λ = 5.452 µm, band = 1A
# Processing slice 692/3438: λ = 5.453 µm, band = 1A
# Processing slice 693/3438: λ = 5.454 µm, band = 1A
# Processing slice 694/3438: λ = 5.455 µm, band = 1A
# Processing slice 695/3438: λ = 5.456 µm, band = 1A
# Processing slice 696/3438: λ = 5.456 µm, band = 1A
# Processing slice 697/3438: λ = 5.457 µm, band = 1A
# Processing slice 698/3438: λ = 5.458 µm, band = 1A
# Processing slice 699/3438: λ = 5.459 µm, band = 1A
# Processing slice 700/3438: λ = 5.460 µm, band = 1A
# Processing slice 701/3438: λ = 5.460 µm, band = 1A
# Processing slice 702/3438: λ = 5.461 µm, band = 1A
# Processing slice 703/3438: λ = 5.462 µm, band = 1A
# Processing slice 704/3438: λ = 5.463 µm, band = 1A
# Processing slice 705/3438: λ = 5.464 µm, band = 1A
# Processing slice 706/3438: λ = 5.464 µm, band = 1A
# Processing slice 707/3438: λ = 5.465 µm, band = 1A
# Processing slice 708/3438: λ = 5.466 µm, band = 1A
# Processing slice 709/3438: λ = 5.467 µm, band = 1A
# Processing slice 710/3438: λ = 5.468 µm, band = 1A
# Processing slice 711/3438: λ = 5.468 µm, band = 1A
# Processing slice 712/3438: λ = 5.469 µm, band = 1A
# Processing slice 713/3438: λ = 5.470 µm, band = 1A
# Processing slice 714/3438: λ = 5.471 µm, band = 1A
# Processing slice 715/3438: λ = 5.472 µm, band = 1A
# Processing slice 716/3438: λ = 5.472 µm, band = 1A
# Processing slice 717/3438: λ = 5.473 µm, band = 1A
# Processing slice 718/3438: λ = 5.474 µm, band = 1A
# Processing slice 719/3438: λ = 5.475 µm, band = 1A
# Processing slice 720/3438: λ = 5.476 µm, band = 1A
# Processing slice 721/3438: λ = 5.476 µm, band = 1A
# Processing slice 722/3438: λ = 5.477 µm, band = 1A
# Processing slice 723/3438: λ = 5.478 µm, band = 1A
# Processing slice 724/3438: λ = 5.479 µm, band = 1A
# Processing slice 725/3438: λ = 5.480 µm, band = 1A
# Processing slice 726/3438: λ = 5.480 µm, band = 1A
# Processing slice 727/3438: λ = 5.481 µm, band = 1A
# Processing slice 728/3438: λ = 5.482 µm, band = 1A
# Processing slice 729/3438: λ = 5.483 µm, band = 1A
# Processing slice 730/3438: λ = 5.484 µm, band = 1A
# Processing slice 731/3438: λ = 5.484 µm, band = 1A
# Processing slice 732/3438: λ = 5.485 µm, band = 1A
# Processing slice 733/3438: λ = 5.486 µm, band = 1A
# Processing slice 734/3438: λ = 5.487 µm, band = 1A
# Processing slice 735/3438: λ = 5.488 µm, band = 1A
# Processing slice 736/3438: λ = 5.488 µm, band = 1A
# Processing slice 737/3438: λ = 5.489 µm, band = 1A
# Processing slice 738/3438: λ = 5.490 µm, band = 1A
# Processing slice 739/3438: λ = 5.491 µm, band = 1A
# Processing slice 740/3438: λ = 5.492 µm, band = 1A
# Processing slice 741/3438: λ = 5.492 µm, band = 1A
# Processing slice 742/3438: λ = 5.493 µm, band = 1A
# Processing slice 743/3438: λ = 5.494 µm, band = 1A
# Processing slice 744/3438: λ = 5.495 µm, band = 1A
# Processing slice 745/3438: λ = 5.496 µm, band = 1A
# Processing slice 746/3438: λ = 5.496 µm, band = 1A
# Processing slice 747/3438: λ = 5.497 µm, band = 1A
# Processing slice 748/3438: λ = 5.498 µm, band = 1A
# Processing slice 749/3438: λ = 5.499 µm, band = 1A
# Processing slice 750/3438: λ = 5.500 µm, band = 1A
# Processing slice 751/3438: λ = 5.500 µm, band = 1A
# Processing slice 752/3438: λ = 5.501 µm, band = 1A
# Processing slice 753/3438: λ = 5.502 µm, band = 1A
# Processing slice 754/3438: λ = 5.503 µm, band = 1A
# Processing slice 755/3438: λ = 5.504 µm, band = 1A
# Processing slice 756/3438: λ = 5.504 µm, band = 1A
# Processing slice 757/3438: λ = 5.505 µm, band = 1A
# Processing slice 758/3438: λ = 5.506 µm, band = 1A
# Processing slice 759/3438: λ = 5.507 µm, band = 1A
# Processing slice 760/3438: λ = 5.508 µm, band = 1A
# Processing slice 761/3438: λ = 5.508 µm, band = 1A
# Processing slice 762/3438: λ = 5.509 µm, band = 1A
# Processing slice 763/3438: λ = 5.510 µm, band = 1A
# Processing slice 764/3438: λ = 5.511 µm, band = 1A
# Processing slice 765/3438: λ = 5.512 µm, band = 1A
# Processing slice 766/3438: λ = 5.512 µm, band = 1A
# Processing slice 767/3438: λ = 5.513 µm, band = 1A
# Processing slice 768/3438: λ = 5.514 µm, band = 1A
# Processing slice 769/3438: λ = 5.515 µm, band = 1A
# Processing slice 770/3438: λ = 5.516 µm, band = 1A
# Processing slice 771/3438: λ = 5.516 µm, band = 1A
# Processing slice 772/3438: λ = 5.517 µm, band = 1A
# Processing slice 773/3438: λ = 5.518 µm, band = 1A
# Processing slice 774/3438: λ = 5.519 µm, band = 1A
# Processing slice 775/3438: λ = 5.520 µm, band = 1A
# Processing slice 776/3438: λ = 5.520 µm, band = 1A
# Processing slice 777/3438: λ = 5.521 µm, band = 1A
# Processing slice 778/3438: λ = 5.522 µm, band = 1A
# Processing slice 779/3438: λ = 5.523 µm, band = 1A
# Processing slice 780/3438: λ = 5.524 µm, band = 1A
# Processing slice 781/3438: λ = 5.524 µm, band = 1A
# Processing slice 782/3438: λ = 5.525 µm, band = 1A
# Processing slice 783/3438: λ = 5.526 µm, band = 1A
# Processing slice 784/3438: λ = 5.527 µm, band = 1A
# Processing slice 785/3438: λ = 5.528 µm, band = 1A
# Processing slice 786/3438: λ = 5.528 µm, band = 1A
# Processing slice 787/3438: λ = 5.529 µm, band = 1A
# Processing slice 788/3438: λ = 5.530 µm, band = 1A
# Processing slice 789/3438: λ = 5.531 µm, band = 1A
# Processing slice 790/3438: λ = 5.532 µm, band = 1A
# Processing slice 791/3438: λ = 5.532 µm, band = 1A
# Processing slice 792/3438: λ = 5.533 µm, band = 1A
# Processing slice 793/3438: λ = 5.534 µm, band = 1A
# Processing slice 794/3438: λ = 5.535 µm, band = 1A
# Processing slice 795/3438: λ = 5.536 µm, band = 1A
# Processing slice 796/3438: λ = 5.536 µm, band = 1A
# Processing slice 797/3438: λ = 5.537 µm, band = 1A
# Processing slice 798/3438: λ = 5.538 µm, band = 1A
# Processing slice 799/3438: λ = 5.539 µm, band = 1A
# Processing slice 800/3438: λ = 5.540 µm, band = 1A
# Processing slice 801/3438: λ = 5.540 µm, band = 1A
# Processing slice 802/3438: λ = 5.541 µm, band = 1A
# Processing slice 803/3438: λ = 5.542 µm, band = 1A
# Processing slice 804/3438: λ = 5.543 µm, band = 1A
# Processing slice 805/3438: λ = 5.544 µm, band = 1A
# Processing slice 806/3438: λ = 5.544 µm, band = 1A
# Processing slice 807/3438: λ = 5.545 µm, band = 1A
# Processing slice 808/3438: λ = 5.546 µm, band = 1A
# Processing slice 809/3438: λ = 5.547 µm, band = 1A
# Processing slice 810/3438: λ = 5.548 µm, band = 1A
# Processing slice 811/3438: λ = 5.548 µm, band = 1A
# Processing slice 812/3438: λ = 5.549 µm, band = 1A
# Processing slice 813/3438: λ = 5.550 µm, band = 1A
# Processing slice 814/3438: λ = 5.551 µm, band = 1A
# Processing slice 815/3438: λ = 5.552 µm, band = 1A
# Processing slice 816/3438: λ = 5.552 µm, band = 1A
# Processing slice 817/3438: λ = 5.553 µm, band = 1A
# Processing slice 818/3438: λ = 5.554 µm, band = 1A
# Processing slice 819/3438: λ = 5.555 µm, band = 1A
# Processing slice 820/3438: λ = 5.556 µm, band = 1A
# Processing slice 821/3438: λ = 5.556 µm, band = 1A
# Processing slice 822/3438: λ = 5.557 µm, band = 1A
# Processing slice 823/3438: λ = 5.558 µm, band = 1A
# Processing slice 824/3438: λ = 5.559 µm, band = 1A
# Processing slice 825/3438: λ = 5.560 µm, band = 1A
# Processing slice 826/3438: λ = 5.560 µm, band = 1A
# Processing slice 827/3438: λ = 5.561 µm, band = 1A
# Processing slice 828/3438: λ = 5.562 µm, band = 1A
# Processing slice 829/3438: λ = 5.563 µm, band = 1A
# Processing slice 830/3438: λ = 5.564 µm, band = 1A
# Processing slice 831/3438: λ = 5.564 µm, band = 1A
# Processing slice 832/3438: λ = 5.565 µm, band = 1A
# Processing slice 833/3438: λ = 5.566 µm, band = 1A
# Processing slice 834/3438: λ = 5.567 µm, band = 1A
# Processing slice 835/3438: λ = 5.568 µm, band = 1A
# Processing slice 836/3438: λ = 5.568 µm, band = 1A
# Processing slice 837/3438: λ = 5.569 µm, band = 1A
# Processing slice 838/3438: λ = 5.570 µm, band = 1A
# Processing slice 839/3438: λ = 5.571 µm, band = 1A
# Processing slice 840/3438: λ = 5.572 µm, band = 1A
# Processing slice 841/3438: λ = 5.572 µm, band = 1A
# Processing slice 842/3438: λ = 5.573 µm, band = 1A
# Processing slice 843/3438: λ = 5.574 µm, band = 1A
# Processing slice 844/3438: λ = 5.575 µm, band = 1A
# Processing slice 845/3438: λ = 5.576 µm, band = 1A
# Processing slice 846/3438: λ = 5.576 µm, band = 1A
# Processing slice 847/3438: λ = 5.577 µm, band = 1A
# Processing slice 848/3438: λ = 5.578 µm, band = 1A
# Processing slice 849/3438: λ = 5.579 µm, band = 1A
# Processing slice 850/3438: λ = 5.580 µm, band = 1A
# Processing slice 851/3438: λ = 5.580 µm, band = 1A
# Processing slice 852/3438: λ = 5.581 µm, band = 1A
# Processing slice 853/3438: λ = 5.582 µm, band = 1A
# Processing slice 854/3438: λ = 5.583 µm, band = 1A
# Processing slice 855/3438: λ = 5.584 µm, band = 1A
# Processing slice 856/3438: λ = 5.584 µm, band = 1A
# Processing slice 857/3438: λ = 5.585 µm, band = 1A
# Processing slice 858/3438: λ = 5.586 µm, band = 1A
# Processing slice 859/3438: λ = 5.587 µm, band = 1A
# Processing slice 860/3438: λ = 5.588 µm, band = 1A
# Processing slice 861/3438: λ = 5.588 µm, band = 1A
# Processing slice 862/3438: λ = 5.589 µm, band = 1A
# Processing slice 863/3438: λ = 5.590 µm, band = 1A
# Processing slice 864/3438: λ = 5.591 µm, band = 1A
# Processing slice 865/3438: λ = 5.592 µm, band = 1A
# Processing slice 866/3438: λ = 5.592 µm, band = 1A
# Processing slice 867/3438: λ = 5.593 µm, band = 1A
# Processing slice 868/3438: λ = 5.594 µm, band = 1A
# Processing slice 869/3438: λ = 5.595 µm, band = 1A
# Processing slice 870/3438: λ = 5.596 µm, band = 1A
# Processing slice 871/3438: λ = 5.596 µm, band = 1A
# Processing slice 872/3438: λ = 5.597 µm, band = 1A
# Processing slice 873/3438: λ = 5.598 µm, band = 1A
# Processing slice 874/3438: λ = 5.599 µm, band = 1A
# Processing slice 875/3438: λ = 5.600 µm, band = 1A
# Processing slice 876/3438: λ = 5.600 µm, band = 1A
# Processing slice 877/3438: λ = 5.601 µm, band = 1A
# Processing slice 878/3438: λ = 5.602 µm, band = 1A
# Processing slice 879/3438: λ = 5.603 µm, band = 1A
# Processing slice 880/3438: λ = 5.604 µm, band = 1A
# Processing slice 881/3438: λ = 5.604 µm, band = 1A
# Processing slice 882/3438: λ = 5.605 µm, band = 1A
# Processing slice 883/3438: λ = 5.606 µm, band = 1A
# Processing slice 884/3438: λ = 5.607 µm, band = 1A
# Processing slice 885/3438: λ = 5.608 µm, band = 1A
# Processing slice 886/3438: λ = 5.608 µm, band = 1A
# Processing slice 887/3438: λ = 5.609 µm, band = 1A
# Processing slice 888/3438: λ = 5.610 µm, band = 1A
# Processing slice 889/3438: λ = 5.611 µm, band = 1A
# Processing slice 890/3438: λ = 5.612 µm, band = 1A
# Processing slice 891/3438: λ = 5.612 µm, band = 1A
# Processing slice 892/3438: λ = 5.613 µm, band = 1A
# Processing slice 893/3438: λ = 5.614 µm, band = 1A
# Processing slice 894/3438: λ = 5.615 µm, band = 1A
# Processing slice 895/3438: λ = 5.616 µm, band = 1A
# Processing slice 896/3438: λ = 5.616 µm, band = 1A
# Processing slice 897/3438: λ = 5.617 µm, band = 1A
# Processing slice 898/3438: λ = 5.618 µm, band = 1A
# Processing slice 899/3438: λ = 5.619 µm, band = 1A
# Processing slice 900/3438: λ = 5.620 µm, band = 1A
# Processing slice 901/3438: λ = 5.620 µm, band = 1A
# Processing slice 902/3438: λ = 5.621 µm, band = 1A
# Processing slice 903/3438: λ = 5.622 µm, band = 1A
# Processing slice 904/3438: λ = 5.623 µm, band = 1A
# Processing slice 905/3438: λ = 5.624 µm, band = 1A
# Processing slice 906/3438: λ = 5.624 µm, band = 1A
# Processing slice 907/3438: λ = 5.625 µm, band = 1A
# Processing slice 908/3438: λ = 5.626 µm, band = 1A
# Processing slice 909/3438: λ = 5.627 µm, band = 1A
# Processing slice 910/3438: λ = 5.628 µm, band = 1A
# Processing slice 911/3438: λ = 5.628 µm, band = 1A
# Processing slice 912/3438: λ = 5.629 µm, band = 1A
# Processing slice 913/3438: λ = 5.630 µm, band = 1A
# Processing slice 914/3438: λ = 5.631 µm, band = 1A
# Processing slice 915/3438: λ = 5.632 µm, band = 1A
# Processing slice 916/3438: λ = 5.632 µm, band = 1A
# Processing slice 917/3438: λ = 5.633 µm, band = 1A
# Processing slice 918/3438: λ = 5.634 µm, band = 1A
# Processing slice 919/3438: λ = 5.635 µm, band = 1A
# Processing slice 920/3438: λ = 5.636 µm, band = 1A
# Processing slice 921/3438: λ = 5.636 µm, band = 1A
# Processing slice 922/3438: λ = 5.637 µm, band = 1A
# ...
# Processing slice 2273/2572: λ = 17.231 µm, band = 3C
# Processing slice 2274/2572: λ = 17.234 µm, band = 3C
# Processing slice 2275/2572: λ = 17.236 µm, band = 3C
# Processing slice 2276/2572: λ = 17.239 µm, band = 3C
# Processing slice 2277/2572: λ = 17.241 µm, band = 3C
# Processing slice 2278/2572: λ = 17.244 µm, band = 3C
# Processing slice 2279/2572: λ = 17.246 µm, band = 3C
# Processing slice 2280/2572: λ = 17.249 µm, band = 3C
# Processing slice 2281/2572: λ = 17.251 µm, band = 3C
# Processing slice 2282/2572: λ = 17.254 µm, band = 3C
# Processing slice 2283/2572: λ = 17.256 µm, band = 3C
# Processing slice 2284/2572: λ = 17.259 µm, band = 3C
# Processing slice 2285/2572: λ = 17.261 µm, band = 3C
# Processing slice 2286/2572: λ = 17.264 µm, band = 3C
# Processing slice 2287/2572: λ = 17.266 µm, band = 3C
# Processing slice 2288/2572: λ = 17.269 µm, band = 3C
# Processing slice 2289/2572: λ = 17.271 µm, band = 3C
# Processing slice 2290/2572: λ = 17.274 µm, band = 3C
# Processing slice 2291/2572: λ = 17.276 µm, band = 3C
# Processing slice 2292/2572: λ = 17.279 µm, band = 3C
# Processing slice 2293/2572: λ = 17.281 µm, band = 3C
# Processing slice 2294/2572: λ = 17.284 µm, band = 3C
# Processing slice 2295/2572: λ = 17.286 µm, band = 3C
# Processing slice 2296/2572: λ = 17.289 µm, band = 3C
# Processing slice 2297/2572: λ = 17.291 µm, band = 3C
# Processing slice 2298/2572: λ = 17.294 µm, band = 3C
# Processing slice 2299/2572: λ = 17.296 µm, band = 3C
# Processing slice 2300/2572: λ = 17.299 µm, band = 3C
# Processing slice 2301/2572: λ = 17.301 µm, band = 3C
# Processing slice 2302/2572: λ = 17.304 µm, band = 3C
# Processing slice 2303/2572: λ = 17.306 µm, band = 3C
# Processing slice 2304/2572: λ = 17.309 µm, band = 3C
# Processing slice 2305/2572: λ = 17.311 µm, band = 3C
# Processing slice 2306/2572: λ = 17.314 µm, band = 3C
# Processing slice 2307/2572: λ = 17.316 µm, band = 3C
# Processing slice 2308/2572: λ = 17.319 µm, band = 3C
# Processing slice 2309/2572: λ = 17.321 µm, band = 3C
# Processing slice 2310/2572: λ = 17.324 µm, band = 3C
# Processing slice 2311/2572: λ = 17.326 µm, band = 3C
# Processing slice 2312/2572: λ = 17.329 µm, band = 3C
# Processing slice 2313/2572: λ = 17.331 µm, band = 3C
# Processing slice 2314/2572: λ = 17.334 µm, band = 3C
# Processing slice 2315/2572: λ = 17.336 µm, band = 3C
# Processing slice 2316/2572: λ = 17.339 µm, band = 3C
# Processing slice 2317/2572: λ = 17.341 µm, band = 3C
# Processing slice 2318/2572: λ = 17.344 µm, band = 3C
# Processing slice 2319/2572: λ = 17.346 µm, band = 3C
# Processing slice 2320/2572: λ = 17.349 µm, band = 3C
# Processing slice 2321/2572: λ = 17.351 µm, band = 3C
# Processing slice 2322/2572: λ = 17.354 µm, band = 3C
# Processing slice 2323/2572: λ = 17.356 µm, band = 3C
# Processing slice 2324/2572: λ = 17.359 µm, band = 3C
# Processing slice 2325/2572: λ = 17.361 µm, band = 3C
# Processing slice 2326/2572: λ = 17.364 µm, band = 3C
# Processing slice 2327/2572: λ = 17.366 µm, band = 3C
# Processing slice 2328/2572: λ = 17.369 µm, band = 3C
# Processing slice 2329/2572: λ = 17.371 µm, band = 3C
# Processing slice 2330/2572: λ = 17.374 µm, band = 3C
# Processing slice 2331/2572: λ = 17.376 µm, band = 3C
# Processing slice 2332/2572: λ = 17.379 µm, band = 3C
# Processing slice 2333/2572: λ = 17.381 µm, band = 3C
# Processing slice 2334/2572: λ = 17.384 µm, band = 3C
# Processing slice 2335/2572: λ = 17.386 µm, band = 3C
# Processing slice 2336/2572: λ = 17.389 µm, band = 3C
# Processing slice 2337/2572: λ = 17.391 µm, band = 3C
# Processing slice 2338/2572: λ = 17.394 µm, band = 3C
# Processing slice 2339/2572: λ = 17.396 µm, band = 3C
# Processing slice 2340/2572: λ = 17.399 µm, band = 3C
# Processing slice 2341/2572: λ = 17.401 µm, band = 3C
# Processing slice 2342/2572: λ = 17.404 µm, band = 3C
# Processing slice 2343/2572: λ = 17.406 µm, band = 3C
# Processing slice 2344/2572: λ = 17.409 µm, band = 3C
# Processing slice 2345/2572: λ = 17.411 µm, band = 3C
# Processing slice 2346/2572: λ = 17.414 µm, band = 3C
# Processing slice 2347/2572: λ = 17.416 µm, band = 3C
# Processing slice 2348/2572: λ = 17.419 µm, band = 3C
# Processing slice 2349/2572: λ = 17.421 µm, band = 3C
# Processing slice 2350/2572: λ = 17.424 µm, band = 3C
# Processing slice 2351/2572: λ = 17.426 µm, band = 3C
# Processing slice 2352/2572: λ = 17.429 µm, band = 3C
# Processing slice 2353/2572: λ = 17.431 µm, band = 3C
# Processing slice 2354/2572: λ = 17.434 µm, band = 3C
# Processing slice 2355/2572: λ = 17.436 µm, band = 3C
# Processing slice 2356/2572: λ = 17.439 µm, band = 3C
# Processing slice 2357/2572: λ = 17.441 µm, band = 3C
# Processing slice 2358/2572: λ = 17.444 µm, band = 3C
# Processing slice 2359/2572: λ = 17.446 µm, band = 3C
# Processing slice 2360/2572: λ = 17.449 µm, band = 3C
# Processing slice 2361/2572: λ = 17.451 µm, band = 3C
# Processing slice 2362/2572: λ = 17.454 µm, band = 3C
# Processing slice 2363/2572: λ = 17.456 µm, band = 3C
# Processing slice 2364/2572: λ = 17.459 µm, band = 3C
# Processing slice 2365/2572: λ = 17.461 µm, band = 3C
# Processing slice 2366/2572: λ = 17.464 µm, band = 3C
# Processing slice 2367/2572: λ = 17.466 µm, band = 3C
# Processing slice 2368/2572: λ = 17.469 µm, band = 3C
# Processing slice 2369/2572: λ = 17.471 µm, band = 3C
# Processing slice 2370/2572: λ = 17.474 µm, band = 3C
# Processing slice 2371/2572: λ = 17.476 µm, band = 3C
# Processing slice 2372/2572: λ = 17.479 µm, band = 3C
# Processing slice 2373/2572: λ = 17.481 µm, band = 3C
# Processing slice 2374/2572: λ = 17.484 µm, band = 3C
# Processing slice 2375/2572: λ = 17.486 µm, band = 3C
# Processing slice 2376/2572: λ = 17.489 µm, band = 3C
# Processing slice 2377/2572: λ = 17.491 µm, band = 3C
# Processing slice 2378/2572: λ = 17.494 µm, band = 3C
# Processing slice 2379/2572: λ = 17.496 µm, band = 3C
# Processing slice 2380/2572: λ = 17.499 µm, band = 3C
# Processing slice 2381/2572: λ = 17.501 µm, band = 3C
# Processing slice 2382/2572: λ = 17.504 µm, band = 3C
# Processing slice 2383/2572: λ = 17.506 µm, band = 3C
# Processing slice 2384/2572: λ = 17.509 µm, band = 3C
# Processing slice 2385/2572: λ = 17.511 µm, band = 3C
# Processing slice 2386/2572: λ = 17.514 µm, band = 3C
# Processing slice 2387/2572: λ = 17.516 µm, band = 3C
# Processing slice 2388/2572: λ = 17.519 µm, band = 3C
# Processing slice 2389/2572: λ = 17.521 µm, band = 3C
# Processing slice 2390/2572: λ = 17.524 µm, band = 3C
# Processing slice 2391/2572: λ = 17.526 µm, band = 3C
# Processing slice 2392/2572: λ = 17.529 µm, band = 3C
# Processing slice 2393/2572: λ = 17.531 µm, band = 3C
# Processing slice 2394/2572: λ = 17.534 µm, band = 3C
# Processing slice 2395/2572: λ = 17.536 µm, band = 3C
# Processing slice 2396/2572: λ = 17.539 µm, band = 3C
# Processing slice 2397/2572: λ = 17.541 µm, band = 3C
# Processing slice 2398/2572: λ = 17.544 µm, band = 3C
# Processing slice 2399/2572: λ = 17.546 µm, band = 3C
# Processing slice 2400/2572: λ = 17.549 µm, band = 3C
# Processing slice 2401/2572: λ = 17.551 µm, band = 3C
# Processing slice 2402/2572: λ = 17.554 µm, band = 3C
# Processing slice 2403/2572: λ = 17.556 µm, band = 3C
# Processing slice 2404/2572: λ = 17.559 µm, band = 3C
# Processing slice 2405/2572: λ = 17.561 µm, band = 3C
# Processing slice 2406/2572: λ = 17.564 µm, band = 3C
# Processing slice 2407/2572: λ = 17.566 µm, band = 3C
# Processing slice 2408/2572: λ = 17.569 µm, band = 3C
# Processing slice 2409/2572: λ = 17.571 µm, band = 3C
# Processing slice 2410/2572: λ = 17.574 µm, band = 3C
# Processing slice 2411/2572: λ = 17.576 µm, band = 3C
# Processing slice 2412/2572: λ = 17.579 µm, band = 3C
# Processing slice 2413/2572: λ = 17.581 µm, band = 3C
# Processing slice 2414/2572: λ = 17.584 µm, band = 3C
# Processing slice 2415/2572: λ = 17.586 µm, band = 3C
# Processing slice 2416/2572: λ = 17.589 µm, band = 3C
# Processing slice 2417/2572: λ = 17.591 µm, band = 3C
# Processing slice 2418/2572: λ = 17.594 µm, band = 3C
# Processing slice 2419/2572: λ = 17.596 µm, band = 3C
# Processing slice 2420/2572: λ = 17.599 µm, band = 3C
# Processing slice 2421/2572: λ = 17.601 µm, band = 3C
# Processing slice 2422/2572: λ = 17.604 µm, band = 3C
# Processing slice 2423/2572: λ = 17.606 µm, band = 3C
# Processing slice 2424/2572: λ = 17.609 µm, band = 3C
# Processing slice 2425/2572: λ = 17.611 µm, band = 3C
# Processing slice 2426/2572: λ = 17.614 µm, band = 3C
# Processing slice 2427/2572: λ = 17.616 µm, band = 3C
# Processing slice 2428/2572: λ = 17.619 µm, band = 3C
# Processing slice 2429/2572: λ = 17.621 µm, band = 3C
# Processing slice 2430/2572: λ = 17.624 µm, band = 3C
# Processing slice 2431/2572: λ = 17.626 µm, band = 3C
# Processing slice 2432/2572: λ = 17.629 µm, band = 3C
# Processing slice 2433/2572: λ = 17.631 µm, band = 3C
# Processing slice 2434/2572: λ = 17.634 µm, band = 3C
# Processing slice 2435/2572: λ = 17.636 µm, band = 3C
# Processing slice 2436/2572: λ = 17.639 µm, band = 3C
# Processing slice 2437/2572: λ = 17.641 µm, band = 3C
# Processing slice 2438/2572: λ = 17.644 µm, band = 3C
# Processing slice 2439/2572: λ = 17.646 µm, band = 3C
# Processing slice 2440/2572: λ = 17.649 µm, band = 3C
# Processing slice 2441/2572: λ = 17.651 µm, band = 3C
# Processing slice 2442/2572: λ = 17.654 µm, band = 3C
# Processing slice 2443/2572: λ = 17.656 µm, band = 3C
# Processing slice 2444/2572: λ = 17.659 µm, band = 3C
# Processing slice 2445/2572: λ = 17.661 µm, band = 3C
# Processing slice 2446/2572: λ = 17.664 µm, band = 3C
# Processing slice 2447/2572: λ = 17.666 µm, band = 3C
# Processing slice 2448/2572: λ = 17.669 µm, band = 3C
# Processing slice 2449/2572: λ = 17.671 µm, band = 3C
# Processing slice 2450/2572: λ = 17.674 µm, band = 3C
# Processing slice 2451/2572: λ = 17.676 µm, band = 3C
# Processing slice 2452/2572: λ = 17.679 µm, band = 3C
# Processing slice 2453/2572: λ = 17.681 µm, band = 3C
# Processing slice 2454/2572: λ = 17.684 µm, band = 3C
# Processing slice 2455/2572: λ = 17.686 µm, band = 3C
# Processing slice 2456/2572: λ = 17.689 µm, band = 3C
# Processing slice 2457/2572: λ = 17.691 µm, band = 3C
# Processing slice 2458/2572: λ = 17.694 µm, band = 3C
# Processing slice 2459/2572: λ = 17.696 µm, band = 3C
# Processing slice 2460/2572: λ = 17.699 µm, band = 3C
# Processing slice 2461/2572: λ = 17.701 µm, band = 3C
# Processing slice 2462/2572: λ = 17.704 µm, band = 3C
# Processing slice 2463/2572: λ = 17.706 µm, band = 3C
# Processing slice 2464/2572: λ = 17.709 µm, band = 3C
# Processing slice 2465/2572: λ = 17.711 µm, band = 3C
# Processing slice 2466/2572: λ = 17.714 µm, band = 3C
# Processing slice 2467/2572: λ = 17.716 µm, band = 3C
# Processing slice 2468/2572: λ = 17.719 µm, band = 3C
# Processing slice 2469/2572: λ = 17.721 µm, band = 3C
# Processing slice 2470/2572: λ = 17.724 µm, band = 3C
# Processing slice 2471/2572: λ = 17.726 µm, band = 3C
# Processing slice 2472/2572: λ = 17.729 µm, band = 3C
# Processing slice 2473/2572: λ = 17.731 µm, band = 3C
# Processing slice 2474/2572: λ = 17.734 µm, band = 3C
# Processing slice 2475/2572: λ = 17.736 µm, band = 3C
# Processing slice 2476/2572: λ = 17.739 µm, band = 3C
# Processing slice 2477/2572: λ = 17.741 µm, band = 3C
# Processing slice 2478/2572: λ = 17.744 µm, band = 3C
# Processing slice 2479/2572: λ = 17.746 µm, band = 3C
# Processing slice 2480/2572: λ = 17.749 µm, band = 3C
# Processing slice 2481/2572: λ = 17.751 µm, band = 3C
# Processing slice 2482/2572: λ = 17.754 µm, band = 3C
# Processing slice 2483/2572: λ = 17.756 µm, band = 3C
# Processing slice 2484/2572: λ = 17.759 µm, band = 3C
# Processing slice 2485/2572: λ = 17.761 µm, band = 3C
# Processing slice 2486/2572: λ = 17.764 µm, band = 3C
# Processing slice 2487/2572: λ = 17.766 µm, band = 3C
# Processing slice 2488/2572: λ = 17.769 µm, band = 3C
# Processing slice 2489/2572: λ = 17.771 µm, band = 3C
# Processing slice 2490/2572: λ = 17.774 µm, band = 3C
# Processing slice 2491/2572: λ = 17.776 µm, band = 3C
# Processing slice 2492/2572: λ = 17.779 µm, band = 3C
# Processing slice 2493/2572: λ = 17.781 µm, band = 3C
# Processing slice 2494/2572: λ = 17.784 µm, band = 3C
# Processing slice 2495/2572: λ = 17.786 µm, band = 3C
# Processing slice 2496/2572: λ = 17.789 µm, band = 3C
# Processing slice 2497/2572: λ = 17.791 µm, band = 3C
# Processing slice 2498/2572: λ = 17.794 µm, band = 3C
# Processing slice 2499/2572: λ = 17.796 µm, band = 3C
# Processing slice 2500/2572: λ = 17.799 µm, band = 3C
# Processing slice 2501/2572: λ = 17.801 µm, band = 3C
# Processing slice 2502/2572: λ = 17.804 µm, band = 3C
# Processing slice 2503/2572: λ = 17.806 µm, band = 3C
# Processing slice 2504/2572: λ = 17.809 µm, band = 3C
# Processing slice 2505/2572: λ = 17.811 µm, band = 3C
# Processing slice 2506/2572: λ = 17.814 µm, band = 3C
# Processing slice 2507/2572: λ = 17.816 µm, band = 3C
# Processing slice 2508/2572: λ = 17.819 µm, band = 3C
# Processing slice 2509/2572: λ = 17.821 µm, band = 3C
# Processing slice 2510/2572: λ = 17.824 µm, band = 3C
# Processing slice 2511/2572: λ = 17.826 µm, band = 3C
# Processing slice 2512/2572: λ = 17.829 µm, band = 3C
# Processing slice 2513/2572: λ = 17.831 µm, band = 3C
# Processing slice 2514/2572: λ = 17.834 µm, band = 3C
# Processing slice 2515/2572: λ = 17.836 µm, band = 3C
# Processing slice 2516/2572: λ = 17.839 µm, band = 3C
# Processing slice 2517/2572: λ = 17.841 µm, band = 3C
# Processing slice 2518/2572: λ = 17.844 µm, band = 3C
# Processing slice 2519/2572: λ = 17.846 µm, band = 3C
# Processing slice 2520/2572: λ = 17.849 µm, band = 3C
# Processing slice 2521/2572: λ = 17.851 µm, band = 3C
# Processing slice 2522/2572: λ = 17.854 µm, band = 3C
# Processing slice 2523/2572: λ = 17.856 µm, band = 3C
# Processing slice 2524/2572: λ = 17.859 µm, band = 3C
# Processing slice 2525/2572: λ = 17.861 µm, band = 3C
# Processing slice 2526/2572: λ = 17.864 µm, band = 3C
# Processing slice 2527/2572: λ = 17.866 µm, band = 3C
# Processing slice 2528/2572: λ = 17.869 µm, band = 3C
# Processing slice 2529/2572: λ = 17.871 µm, band = 3C
# Processing slice 2530/2572: λ = 17.874 µm, band = 3C
# Processing slice 2531/2572: λ = 17.876 µm, band = 3C
# Processing slice 2532/2572: λ = 17.879 µm, band = 3C
# Processing slice 2533/2572: λ = 17.881 µm, band = 3C
# Processing slice 2534/2572: λ = 17.884 µm, band = 3C
# Processing slice 2535/2572: λ = 17.886 µm, band = 3C
# Processing slice 2536/2572: λ = 17.889 µm, band = 3C
# Processing slice 2537/2572: λ = 17.891 µm, band = 3C
# Processing slice 2538/2572: λ = 17.894 µm, band = 3C
# Processing slice 2539/2572: λ = 17.896 µm, band = 3C
# Processing slice 2540/2572: λ = 17.899 µm, band = 3C
# Processing slice 2541/2572: λ = 17.901 µm, band = 3C
# Processing slice 2542/2572: λ = 17.904 µm, band = 3C
# Processing slice 2543/2572: λ = 17.906 µm, band = 3C
# Processing slice 2544/2572: λ = 17.909 µm, band = 3C
# Processing slice 2545/2572: λ = 17.911 µm, band = 3C
# Processing slice 2546/2572: λ = 17.914 µm, band = 3C
# Processing slice 2547/2572: λ = 17.916 µm, band = 3C
# Processing slice 2548/2572: λ = 17.919 µm, band = 3C
# Processing slice 2549/2572: λ = 17.921 µm, band = 3C
# Processing slice 2550/2572: λ = 17.924 µm, band = 3C
# Processing slice 2551/2572: λ = 17.926 µm, band = 3C
# Processing slice 2552/2572: λ = 17.929 µm, band = 3C
# Processing slice 2553/2572: λ = 17.931 µm, band = 3C
# Processing slice 2554/2572: λ = 17.934 µm, band = 3C
# Processing slice 2555/2572: λ = 17.936 µm, band = 3C
# Processing slice 2556/2572: λ = 17.939 µm, band = 3C
# Processing slice 2557/2572: λ = 17.941 µm, band = 3C
# Processing slice 2558/2572: λ = 17.944 µm, band = 3C
# Processing slice 2559/2572: λ = 17.946 µm, band = 3C
# Processing slice 2560/2572: λ = 17.949 µm, band = 3C
# Processing slice 2561/2572: λ = 17.951 µm, band = 3C
# Processing slice 2562/2572: λ = 17.954 µm, band = 3C
# Processing slice 2563/2572: λ = 17.956 µm, band = 3C
# Processing slice 2564/2572: λ = 17.959 µm, band = 3C
# Processing slice 2565/2572: λ = 17.961 µm, band = 3C
# Processing slice 2566/2572: λ = 17.964 µm, band = 3C
# Processing slice 2567/2572: λ = 17.966 µm, band = 3C
# Processing slice 2568/2572: λ = 17.969 µm, band = 3C
# Processing slice 2569/2572: λ = 17.971 µm, band = 3C
# Processing slice 2570/2572: λ = 17.974 µm, band = 3C
# Processing slice 2571/2572: λ = 17.976 µm, band = 3C
# Processing slice 2572/2572: λ = 17.979 µm, band = 3C
# Wrote ./psf_smooth_cubes/NGC253_sky_v1_17_1_ch3-smooth.fits, shape=(2572, 93, 75)

# %%
#Comparision 

# Choose your own file, please make sure to use same wavelength kernel for Gaussian smoothing
# I will link a repo for that too and put link here if you want to know how to impliment that
gauss_file = "../../github/astr796_25_V2/Task5/3channel/final_cube/NGC253_sky_v1_17_1_ch1-shortmediumlong_s3d_smooth.regrid-ch3.mask.fits"
psf_file   = "../../github/astr796_25_V2/Task5/3channel/psf/final_cube/NGC253_sky_v1_17_1_ch1-shortmediumlong_s3d_smooth.regrid-ch3.mask.fits"

#psf_file   = "../../github/astr796_25_V2/Task5/3channel/psf_smooth_cubes/NGC253_ch1_psfmatched.fits"

gauss_hdul = fits.open(gauss_file)
psf_hdul   = fits.open(psf_file)

gauss_flux = gauss_hdul['SCI'].data
psf_flux   = psf_hdul['SCI'].data
hdr        = gauss_hdul['SCI'].header

nlam   = hdr['NAXIS3']
crval3 = hdr['CRVAL3']   # starting wavelength
cdelt3 = hdr['CDELT3']   # wavelength step
crpix3 = hdr['CRPIX3']   # reference pixel

idx = np.arange(nlam)
lambdas_um = (idx - (crpix3 - 1)) * cdelt3 + crval3   # wavelength array in microns

#arii_wave = 6.985  # microns, adjust if you use a slightly different value
arii_wave = 5.525   #I am just changing wavelength to see what are the effects on another slice of data
i_arii = np.argmin(np.abs(lambdas_um - arii_wave))
print("Closest slice to [Ar II]:", i_arii, "lambda =", lambdas_um[i_arii])

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

vmin = np.nanpercentile(gauss_flux[i_arii], 5)
vmax = np.nanpercentile(gauss_flux[i_arii], 95)

ax[0].imshow(gauss_flux[i_arii], origin='lower', vmin=vmin, vmax=vmax)
ax[0].set_title(f"Gaussian @ [Ar II] ~ {lambdas_um[i_arii]:.3f} µm")

ax[1].imshow(psf_flux[i_arii], origin='lower', vmin=vmin, vmax=vmax)
ax[1].set_title("JWST PSF smoothed")

ax[2].imshow(psf_flux[i_arii] - gauss_flux[i_arii], origin='lower')
ax[2].set_title("Difference (PSF − Gaussian)")

plt.tight_layout()
plt.show()

slice_gauss = gauss_flux[i_arii]
slice_psf   = psf_flux[i_arii]

diff = slice_psf - slice_gauss

rms_diff = np.nanstd(diff)
print("RMS difference at [Ar II]:", rms_diff)

mean_signal = np.nanmean(slice_gauss)
rel_rms = rms_diff / mean_signal
print("Relative RMS difference (RMS / mean signal):", rel_rms)
mask = np.isfinite(slice_gauss) & np.isfinite(slice_psf)
g = slice_gauss[mask].ravel()
p = slice_psf[mask].ravel()

corr = np.corrcoef(g, p)[0, 1]
print("Pixel-wise correlation at [Ar II]:", corr)
ny, nx = slice_gauss.shape
yc, xc = ny // 2, nx // 2
r = 5  # radius in pixels

y, x = np.indices(slice_gauss.shape)
mask_ap = (x - xc)**2 + (y - yc)**2 <= r**2

flux_gauss_ap = np.nansum(slice_gauss[mask_ap])
flux_psf_ap   = np.nansum(slice_psf[mask_ap])

print("Aperture flux (Gaussian):", flux_gauss_ap)
print("Aperture flux (PSF):     ", flux_psf_ap)
print("Relative difference:", (flux_psf_ap - flux_gauss_ap) / flux_gauss_ap)
# Out:
# Closest slice to [Ar II]: 781 lambda = 5.5252000795735245
# RMS difference at [Ar II]: 613.9505947830113
# Relative RMS difference (RMS / mean signal): 0.5956119841991385
# Pixel-wise correlation at [Ar II]: 0.9343418605788194
# Aperture flux (Gaussian): 378183.23779164016
# Aperture flux (PSF):      326241.70446673257
# Relative difference: -0.1373448850568167

# %%
'''
def smooth_cube_with_error_3d_scipy(infile, outfile):
    """
    Smooth each wavelength slice in 2D (y, x) using the JWST MIRI 3C PSF
    at 17.98 micron instead of a Gaussian.
    """

    from scipy.signal import fftconvolve

    # Read cube
    sc = SpectralCube.read(infile, hdu=1)
    flux = fits.getdata(infile, hdu=1)
    err  = fits.getdata(infile, hdu=2)
    sci_hdr = sc.header.copy()

    # Wavelength array (spectral WCS)
    if all(k in sci_hdr for k in ["CRVAL3", "CDELT3", "CRPIX3"]):
        nlam = sci_hdr["NAXIS3"]
        lambdas = ((np.arange(nlam) - (sci_hdr["CRPIX3"] - 1)) *
                   sci_hdr["CDELT3"] + sci_hdr["CRVAL3"])
    else:
        raise ValueError("Spectral WCS keywords missing from SCI header!")

    # Pixel scale (deg -> arcsec)
    pixscale = sci_hdr["CDELT2"] * 3600.0

    #https://stpsf.readthedocs.io/en/latest/jwst_ifu_datacubes.html#MIRI-MRS-example
    # Allocate output arrays
    sm_flux = np.empty_like(flux)
    sm_err  = np.empty_like(err)

    # --- PRECOMPUTE PSF OUTSIDE LOOP ---
    miri = stpsf.MIRI()
    miri.mode = 'IFU'
    miri.band = '3C'
    miri.pixelscale = pixscale

    psf = miri.calc_psf(monochromatic=17.98 * u.micron) #https://stpsf.readthedocs.io/en/latest/api/stpsf.JWInstrument.html#stpsf.JWInstrument.calc_psf
    psf_kernel = psf[1].data.astype(float) #0-header only 1- data
    psf_kernel /= psf_kernel.sum() #normalization

    # Loop over slices and apply PSF convolution
    for i in range(nlam):

        img = np.nan_to_num(flux[i], nan=0.0) #extract slice and replace nan
        valid_mask = (~np.isnan(flux[i])).astype(float) #build mask of valid pixel

        # Convolve flux #takes the img input, blur it using jwst psf and return same size output
        sm_slice = fftconvolve(img, psf_kernel, mode='same') #https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.fftconvolve.html
        sm_slice *= valid_mask #this is a memory and the slice will have nan mapped
        sm_slice[valid_mask == 0] = np.nan #this replaces any value in slice with nan which was nan in input
        sm_flux[i] = sm_slice #this is loop over slices 

        #Because I will be using the data into PAHFIT I need to propagate error too
        #If you dont need to do so, look for the line fine method which doesnot have the below step

        # Convolve variance
        var = np.nan_to_num(err[i]**2, nan=0.0) 
        psf_sq = psf_kernel**2
        psf_sq /= psf_sq.sum()

        sm_var = fftconvolve(var, psf_sq, mode='same')
        sm_var = np.clip(sm_var, 0, None)
        sm_err[i] = np.sqrt(sm_var)
        sm_err[i][valid_mask == 0] = np.nan

    # ---- Write FITS in JWST-like structure ----
    primary = fits.PrimaryHDU()
    sci_hdu = fits.ImageHDU(data=sm_flux.astype(np.float32), header=sci_hdr, name='SCI')
    err_hdu = fits.ImageHDU(data=sm_err.astype(np.float32), header=sci_hdr.copy(), name='ERR')
    dq_hdu  = fits.ImageHDU(data=np.zeros_like(sm_flux, dtype=np.uint32),
                            header=sci_hdr.copy(), name='DQ')

    hdul = fits.HDUList([primary, sci_hdu, err_hdu, dq_hdu])
    hdul.writeto(outfile, overwrite=True)

    print(f"Wrote {outfile}, shape={sm_flux.shape}")
    print("  spectral keys:",
          {k: sci_hdr.get(k) for k in ['CRVAL3','CRPIX3','CDELT3','CTYPE3','CUNIT3']})

#Sorry the directories are crazzy on my side please choose to use your own directory
# Ensure output directory exists
outdir = "../../github/astr796_25_V2/Task5/3channel/psf_smooth_cubes"
os.makedirs(outdir, exist_ok=True)

#I cant upload more than 100mb file on github, please get the data from mast or choose the directory of your data
# ---- RUN FOR CHANNELS 1–3 ----
for ch in range(1, 4):
    infile  = f"../../github/astr796_25_V2/files/NGC253_sky_v1_17_1_ch{ch}-shortmediumlong_s3d.fits"
    outfile = f"{outdir}/NGC253_sky_v1_17_1_ch{ch}-shortmediumlong_s3d_smooth_3d.fits"
    smooth_cube_with_error_3d_scipy(infile, outfile)

'''
# Out:
# /Users/u826s018/miniconda3/envs/nearbygalaxies/lib/python3.11/site-packages/stpsf/opds.py:1759: UserWarning: For (V2,V3) = [-8.399315 -5.319645] arcmin, Field point -8.254199999999999 arcmin, -2.480355000000001 arcmin not within valid region for field dependence model of OTE WFE for MIRI: -8.254199999999999 arcmin--6.21738 arcmin, -2.557224 arcmin--0.5632056 arcmin.  Clipping to closest available valid location, 0.14511500000000055 arcmin away from the requested coordinates.
#   warnings.warn(warning_message)
# Wrote ../../github/astr796_25_V2/Task5/3channel/psf_smooth_cubes/NGC253_sky_v1_17_1_ch1-shortmediumlong_s3d_smooth_3d.fits, shape=(3438, 115, 87)
#   spectral keys: {'CRVAL3': 4.9004000953573, 'CRPIX3': 1.0, 'CDELT3': 0.0007999999797903, 'CTYPE3': 'WAVE', 'CUNIT3': 'um'}
# /Users/u826s018/miniconda3/envs/nearbygalaxies/lib/python3.11/site-packages/stpsf/opds.py:1759: UserWarning: For (V2,V3) = [-8.399315 -5.319645] arcmin, Field point -8.254199999999999 arcmin, -2.480355000000001 arcmin not within valid region for field dependence model of OTE WFE for MIRI: -8.254199999999999 arcmin--6.21738 arcmin, -2.557224 arcmin--0.5632056 arcmin.  Clipping to closest available valid location, 0.14511500000000055 arcmin away from the requested coordinates.
#   warnings.warn(warning_message)
# Wrote ../../github/astr796_25_V2/Task5/3channel/psf_smooth_cubes/NGC253_sky_v1_17_1_ch2-shortmediumlong_s3d_smooth_3d.fits, shape=(3224, 97, 75)
#   spectral keys: {'CRVAL3': 7.510650228883599, 'CRPIX3': 1.0, 'CDELT3': 0.001300000003539, 'CTYPE3': 'WAVE', 'CUNIT3': 'um'}
# /Users/u826s018/miniconda3/envs/nearbygalaxies/lib/python3.11/site-packages/stpsf/opds.py:1759: UserWarning: For (V2,V3) = [-8.399315 -5.319645] arcmin, Field point -8.254199999999999 arcmin, -2.480355000000001 arcmin not within valid region for field dependence model of OTE WFE for MIRI: -8.254199999999999 arcmin--6.21738 arcmin, -2.557224 arcmin--0.5632056 arcmin.  Clipping to closest available valid location, 0.14511500000000055 arcmin away from the requested coordinates.
#   warnings.warn(warning_message)
# Wrote ../../github/astr796_25_V2/Task5/3channel/psf_smooth_cubes/NGC253_sky_v1_17_1_ch3-shortmediumlong_s3d_smooth_3d.fits, shape=(2572, 93, 75)
#   spectral keys: {'CRVAL3': 11.551250190707, 'CRPIX3': 1.0, 'CDELT3': 0.0024999999441206, 'CTYPE3': 'WAVE', 'CUNIT3': 'um'}

# %% [markdown]
# ### For individual line files

# %%
# Choose the line file you want to compare
line_name = "NGC253_FeII_5.3.line_smooth.fits"

gauss_file = f"../../github/astr796_25_V2/NGC253_output/3channel/casa/line_smooth/{line_name}"
psf_file   = f"../../github/astr796_25_V2/NGC253_output/3channel/jwst_psf/line_smooth/{line_name}"

# Load cubes
gauss = fits.getdata(gauss_file)
psf   = fits.getdata(psf_file)
hdr   = fits.getheader(gauss_file)

# --- Build wavelength grid from WCS ---
nlam   = hdr["NAXIS3"]
crval3 = hdr["CRVAL3"]
cdelt3 = hdr["CDELT3"]
crpix3 = hdr["CRPIX3"]

idx = np.arange(nlam)
lam = (idx - (crpix3 - 1)) * cdelt3 + crval3   # wavelength array

# This is just picking up the brigtest slice from line file 
# needs to be constrained and still working on this
# If the line file is appropriate the brightest should be the peak thats the logic here for comparision

# --- Automatically pick the brightest slice ---
slice_means = np.nanmean(gauss, axis=(1,2))
i_slice = np.nanargmax(slice_means)

print("Comparing slice index:", i_slice)

# Extract slices
g = gauss[i_slice]
p = psf[i_slice]
d = p - g

# --- Plot ---
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

vmin = np.nanpercentile(g, 5)
vmax = np.nanpercentile(g, 95)

ax[0].imshow(g, origin='lower', vmin=vmin, vmax=vmax)
ax[0].set_title("Gaussian smoothed")

ax[1].imshow(p, origin='lower', vmin=vmin, vmax=vmax)
ax[1].set_title("JWST PSF smoothed")

ax[2].imshow(d, origin='lower')
ax[2].set_title("Difference (PSF − Gaussian)")

plt.tight_layout()
plt.show()

# --- Metrics ---
rms = np.nanstd(d)

mask = np.isfinite(g) & np.isfinite(p)
corr = np.corrcoef(g[mask], p[mask])[0,1]

print("RMS difference:", rms)
print("Correlation:", corr)

# --- Aperture flux comparison ---
ny, nx = g.shape
yc, xc = ny//2, nx//2
r = 5

Y, X = np.indices(g.shape)
mask = (X-xc)**2 + (Y-yc)**2 <= r**2

flux_g = np.nansum(g[mask])
flux_p = np.nansum(p[mask])

print("Aperture flux (Gaussian):", flux_g)
print("Aperture flux (PSF):     ", flux_p)
print("Relative difference:", (flux_p - flux_g)/flux_g)

# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt

# Choose the line file you want to compare
line_name = "NGC253_FeII_5.3.line_smooth.fits"

gauss_file = f"../../github/astr796_25_V2/NGC253_output/3channel/casa/line_smooth/{line_name}"
psf_file   = f"../../github/astr796_25_V2/NGC253_output/3channel/jwst_psf/line_smooth/{line_name}"

# Load cubes
gauss = fits.getdata(gauss_file)
psf   = fits.getdata(psf_file)
hdr   = fits.getheader(gauss_file)

# --- Build wavelength grid from WCS ---
nlam   = hdr["NAXIS3"]
crval3 = hdr["CRVAL3"]
cdelt3 = hdr["CDELT3"]
crpix3 = hdr["CRPIX3"]

idx = np.arange(nlam)
lam = (idx - (crpix3 - 1)) * cdelt3 + crval3

# Convert meters → microns if needed
if hdr.get("CUNIT3", "").lower() == "m":
    lam *= 1e6

#This is not working, I am still looking how to accurately get the targetted wavelength
#as casa tools has messed up headers while extracting line files

# --- Pick slice closest to a given wavelength ---
target_wavelength = 5.34  # microns (Fe II line)
i_slice = np.argmin(np.abs(lam - target_wavelength))

print("Comparing slice index:", i_slice)
print("Wavelength of this slice:", lam[i_slice], "micron")

# Extract slices
g = gauss[i_slice]
p = psf[i_slice]
d = p - g

# --- Plot ---
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

vmin = np.nanpercentile(g, 5)
vmax = np.nanpercentile(g, 95)

ax[0].imshow(g, origin='lower', vmin=vmin, vmax=vmax)
ax[0].set_title("Gaussian smoothed")

ax[1].imshow(p, origin='lower', vmin=vmin, vmax=vmax)
ax[1].set_title("JWST PSF smoothed")

ax[2].imshow(d, origin='lower')
ax[2].set_title("Difference (PSF − Gaussian)")

plt.tight_layout()
plt.show()

# --- Metrics ---
rms = np.nanstd(d)

mask = np.isfinite(g) & np.isfinite(p)
corr = np.corrcoef(g[mask], p[mask])[0,1]

print("RMS difference:", rms)
print("Correlation:", corr)

# --- Aperture flux comparison ---
ny, nx = g.shape
yc, xc = ny//2, nx//2
r = 5

Y, X = np.indices(g.shape)
mask = (X-xc)**2 + (Y-yc)**2 <= r**2

flux_g = np.nansum(g[mask])
flux_p = np.nansum(p[mask])

print("Aperture flux (Gaussian):", flux_g)
print("Aperture flux (PSF):     ", flux_p)
print("Relative difference:", (flux_p - flux_g)/flux_g)
# Out:
# Comparing slice index: 51
# Wavelength of this slice: 55899004622910.6 micron
# RMS difference: 37.72267
# Correlation: 0.8174178662653708
# Aperture flux (Gaussian): 906.56433
# Aperture flux (PSF):      433.0057
# Relative difference: -0.5223663
